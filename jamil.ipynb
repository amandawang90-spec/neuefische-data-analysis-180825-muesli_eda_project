# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("./data/Muesli Project raw data.xlsx", header=1)

# %%
df_orders = pd.read_excel("./data/Muesli Project raw data.xlsx",sheet_name="Orders", header=1)

# %%
df_orders
# Out:
#       Index        Order ID Order Date       Ship Mode Customer ID  \
# 0        27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1        45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2        48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3        60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4        63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
# ...     ...             ...        ...             ...         ...
# 9989   9894  US-2019-115441 2019-07-25    Second Class    SH-19975
# 9990   9908  US-2018-129007 2018-09-13     First Class    KD-16615
# 9991   9913  CA-2018-132388 2018-10-10     First Class    KN-16390
# 9992   9920  CA-2019-149272 2019-03-15  Standard Class    MY-18295
# 9993   9948  CA-2020-121559 2020-06-01    Second Class    HW-14935
#
#           Customer Name Origin Channel Country/Region           City  \
# 0         Eric Hoffmann          Email  United States    Los Angeles
# 1         Odella Nelson          Sales  United States          Eagan
# 2        Lena Hernandez          Email  United States          Dover
# 3       Ted Butterfield          Email  United States           Troy
# 4          Kunst Miller          Email  United States    Los Angeles
# ...                 ...            ...            ...            ...
# 9989      Sally Hughsby          Sales  United States      Milwaukee
# 9990           Ken Dana          Sales  United States        Anaheim
# 9991  Katherine Nockton          Sales  United States  Santa Barbara
# 9992    Muhammed Yedwab          Sales  United States          Bryan
# 9993    Helen Wasserman          Sales  United States   Indianapolis
#
#            State  Postal Code   Region                 Category Sub-Category  \
# 0     California      90049.0     West  Special Projects Muesil  Gluten Free
# 1      Minnesota      55122.0  Central  Special Projects Muesil  Gluten Free
# 2       Delaware      19901.0     East  Special Projects Muesil  Gluten Free
# 3       New York      12180.0     East  Special Projects Muesil  Gluten Free
# 4     California      90004.0     West  Special Projects Muesil  Gluten Free
# ...          ...          ...      ...                      ...          ...
# 9989   Wisconsin      53209.0  Central           Toasted Muesli    With Nuts
# 9990  California      92804.0     West           Toasted Muesli    With Nuts
# 9991  California      93101.0     West           Toasted Muesli    With Nuts
# 9992       Texas      77803.0  Central           Toasted Muesli    With Nuts
# 9993     Indiana      46203.0  Central           Toasted Muesli    With Nuts
#
#            Product ID     Sales  Quantity  Discount    Profit
# 0     TEC-AC-10003027    90.570         3       0.0   11.7741
# 1     TEC-AC-10000171    45.980         2       0.0   19.7714
# 2     TEC-AC-10002167    45.000         3       0.0    4.9500
# 3     TEC-AC-10002167    30.000         2       0.0    3.3000
# 4     TEC-AC-10004633    13.980         2       0.0    6.1512
# ...               ...       ...       ...       ...       ...
# 9989  FUR-CH-10004626   403.560         4       0.0   96.8544
# 9990  FUR-CH-10000155   717.720         3       0.2   71.7720
# 9991  FUR-CH-10001714   362.136         3       0.2  -54.3204
# 9992  FUR-CH-10000863   528.430         5       0.3 -143.4310
# 9993  FUR-CH-10003746  1925.880         6       0.0  539.2464
#
# [9994 rows x 19 columns]

# %%
df_campaign= pd.read_excel("./data/Muesli Project raw data.xlsx", sheet_name="Campaign Data")

# %%
df_campaign
# Out:
#            Order ID Arrival Scan Date     Customer Name
# 0    CA-2019-109666        2019-05-03      Kunst Miller
# 1    CA-2019-138933        2019-05-03       Jack Lebron
# 2    CA-2019-130001        2019-05-03  Heather Kirkland
# 3    CA-2019-113061        2019-05-06         Ed Ludwig
# 4    CA-2019-162138        2019-05-06       Grace Kelly
# ..              ...               ...               ...
# 328  CA-2020-129707        2020-05-08      Larry Hughes
# 329  CA-2020-125381        2020-05-08  Speros Goranitis
# 330  CA-2020-141733        2020-05-15       Rick Wilson
# 331  US-2020-104451        2020-05-15    Michelle Moray
# 332  US-2020-139647        2020-05-15      Todd Sumrall
#
# [333 rows x 3 columns]

# %%
df_order_process=pd.read_excel("./data/Muesli Project raw data.xlsx", sheet_name="Order Process Data")

# %%
df_order_process
# Out:
#       Row ID        Order ID Order Date On Truck Scan Date  \
# 0       3074  CA-2019-125206 2019-01-03         2019-01-07
# 1       4919  CA-2019-160304 2019-01-02         2019-01-09
# 2       4920  CA-2019-160304 2019-01-02         2019-01-09
# 3       8604  US-2019-116365 2019-01-03         2019-01-09
# 4       8605  US-2019-116365 2019-01-03         2019-01-09
# ...      ...             ...        ...                ...
# 5894     908  CA-2020-143259 2020-12-30         2021-01-06
# 5895     909  CA-2020-143259 2020-12-30         2021-01-06
# 5896    1297  CA-2020-115427 2020-12-30         2021-01-06
# 5897    1298  CA-2020-115427 2020-12-30         2021-01-06
# 5898    5092  CA-2020-156720 2020-12-30         2021-01-06
#
#                 Ship Mode
# 0                 Express
# 1     Standard Processing
# 2     Standard Processing
# 3     Standard Processing
# 4     Standard Processing
# ...                   ...
# 5894  Standard Processing
# 5895  Standard Processing
# 5896  Standard Processing
# 5897  Standard Processing
# 5898  Standard Processing
#
# [5899 rows x 5 columns]

# %%
df_intern_data=pd.read_excel("./data/Muesli Project raw data.xlsx", sheet_name="InternData Study")

# %%
df_intern_data
# Out:
#            Order ID Ready to Ship Date Pickup Date
# 0    CA-2019-116540         2019-09-02  2019-09-03
# 1    CA-2019-116540         2019-09-02  2019-09-03
# 2    CA-2019-129847         2019-09-04  2019-09-04
# 3    CA-2019-129630         2019-09-04  2019-09-04
# 4    CA-2019-106278         2019-09-05  2019-09-06
# ..              ...                ...         ...
# 285  CA-2020-105333         2020-12-04  2020-12-07
# 286  CA-2020-105333         2020-12-04  2020-12-07
# 287  US-2020-110576         2020-12-04  2020-12-07
# 288  CA-2020-119305         2020-12-04  2020-12-07
# 289  CA-2020-142090         2020-12-07  2020-12-09
#
# [290 rows x 3 columns]

# %% [markdown]
# ## Merge

# %%
df_1=pd.merge(df_orders, df_campaign, on='Order ID', how='outer')

# %%
df_1
# Out:
#       Index        Order ID Order Date       Ship Mode Customer ID  \
# 0      2718  CA-2017-100006 2017-09-07  Standard Class    DK-13375
# 1      6289  CA-2017-100090 2017-07-08  Standard Class    EB-13705
# 2      6288  CA-2017-100090 2017-07-08  Standard Class    EB-13705
# 3      9515  CA-2017-100293 2017-03-14  Standard Class    NF-18475
# 4      3084  CA-2017-100328 2017-01-28  Standard Class    JC-15340
# ...     ...             ...        ...             ...         ...
# 9989   5935  US-2020-169551 2020-07-07     First Class    RL-19615
# 9990   5931  US-2020-169551 2020-07-07     First Class    RL-19615
# 9991   5932  US-2020-169551 2020-07-07     First Class    RL-19615
# 9992   5933  US-2020-169551 2020-07-07     First Class    RL-19615
# 9993   5930  US-2020-169551 2020-07-07     First Class    RL-19615
#
#        Customer Name_x Origin Channel Country/Region           City  \
# 0          Dennis Kane          Email  United States  New York City
# 1           Ed Braxton          Sales  United States  San Francisco
# 2           Ed Braxton          Sales  United States  San Francisco
# 3     Neil Französisch       Facebook  United States   Jacksonville
# 4      Jasper Cacioppo          Email  United States  New York City
# ...                ...            ...            ...            ...
# 9989         Rob Lucas          Email  United States   Philadelphia
# 9990         Rob Lucas          Email  United States   Philadelphia
# 9991         Rob Lucas          Email  United States   Philadelphia
# 9992         Rob Lucas          Email  United States   Philadelphia
# 9993         Rob Lucas          Email  United States   Philadelphia
#
#              State  ...  Region                 Category       Sub-Category  \
# 0         New York  ...    East  Special Projects Muesil          Only Oats
# 1       California  ...    West             Power Muesli  Super Fibre Boost
# 2       California  ...    West           Toasted Muesli          Sweetened
# 3          Florida  ...   South             Power Muesli      Nuts and more
# 4         New York  ...    East             Power Muesli  Super Fibre Boost
# ...            ...  ...     ...                      ...                ...
# 9989  Pennsylvania  ...    East  Special Projects Muesil        Gluten Free
# 9990  Pennsylvania  ...    East             Power Muesli      Nuts and more
# 9991  Pennsylvania  ...    East  Special Projects Muesil          Only Oats
# 9992  Pennsylvania  ...    East             Power Muesli          Steel Cut
# 9993  Pennsylvania  ...    East           Toasted Muesli         With Fruit
#
#            Product ID    Sales  Quantity  Discount    Profit  \
# 0     TEC-PH-10002075  377.970         3       0.0  109.6113
# 1     OFF-BI-10001597  196.704         6       0.2   68.8464
# 2     FUR-TA-10003715  502.488         3       0.2  -87.9354
# 3     OFF-PA-10000176   91.056         6       0.2   31.8696
# 4     OFF-BI-10000343    3.928         1       0.2    1.3257
# ...               ...      ...       ...       ...       ...
# 9989  TEC-AC-10003033  527.920         2       0.2   85.7870
# 9990  OFF-PA-10004100   15.552         3       0.2    5.4432
# 9991  TEC-PH-10001363  683.988         2       0.4 -113.9980
# 9992  OFF-ST-10004835   13.392         3       0.2    1.0044
# 9993  FUR-BO-10001519   87.210         3       0.5  -45.3492
#
#       Arrival Scan Date Customer Name_y
# 0                   NaT             NaN
# 1                   NaT             NaN
# 2                   NaT             NaN
# 3                   NaT             NaN
# 4                   NaT             NaN
# ...                 ...             ...
# 9989                NaT             NaN
# 9990                NaT             NaN
# 9991                NaT             NaN
# 9992                NaT             NaN
# 9993                NaT             NaN
#
# [9994 rows x 21 columns]

# %%
#df_2=pd.merge(df_1,df_order_process, on='Order ID', how='left')

# %%
#df_2

# %%
#df_total=pd.merge(df_2, df_InternData, on='Order ID', how='outer')
