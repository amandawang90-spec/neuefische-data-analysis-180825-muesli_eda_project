# %% [markdown]
# # Muesli Data Analysis

# %% [markdown]
# ## Pre-Setup

# %% [markdown]
# ### Environment

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")
sns.set_palette("magma")

# %% [markdown]
# ### Read in data

# %%
df_orders = pd.read_excel("./data/Muesli Project raw data.xlsx",sheet_name="Orders",header=1)
df_campaign = pd.read_excel("./data/Muesli Project raw data.xlsx", sheet_name="Campaign Data")
df_order_process = pd.read_excel("./data/Muesli Project raw data.xlsx", sheet_name="Order Process Data")
df_interndata = pd.read_excel("./data/Muesli Project raw data.xlsx", sheet_name="InternData Study")

# %% [markdown]
# ### Raw dataframes

# %%
#df_orders.head(2)

# %%
#df_campaign.head(2)

# %%
#df_order_process.head(2)

# %%
#df_interndata.head(2)

# %% [markdown]
# ### Data cleaning function

# %%
def data_cleaning(df, df_type):
    
    # make col names lower
    df.columns = df.columns.str.lower()
    
   # orders data
    if df_type == "orders":
        # dropping cols
        df = df.drop(["index", "customer name", "origin channel", "category", "sub-category", "product id", "sales", "quantity", "discount", "profit"],axis=1)
        # dropping duplicates
        df = df.drop_duplicates()
        # renaming values in ship mode
        df["ship mode"] = df["ship mode"].str.replace(" Class","")
        df["ship mode"] = df["ship mode"].str.replace("Second","Standard")
        df["ship mode"] = df["ship mode"].str.replace("First","Express")
    
    # campaign data
    elif df_type == "campaign":
        # dropping cols
        df = df.drop("customer name", axis=1)
        # dropping duplicates
        pass

    # order process data    
    elif df_type == "order_process":
        # dropping cols
        df = df.drop("row id", axis=1)
        # dropping duplicates
        df = df.drop_duplicates()
        # dropping 1 duplicate row for id (scanned on truck twice)
        df = df.drop_duplicates(subset=["order id"], keep = "first")
        # dropping column order date, because 100% match with order date in orders data
        df = df.drop("order date", axis=1)
        # dropping column ship mode, because 100% match with ship mode in orders data (assumption: second class shipping = standard)
        df = df.drop("ship mode", axis=1)

    #intern data
    else:
        # dropping cols
        pass
        # dropping duplicates
        df = df.drop_duplicates()
        # dropping column pickup date, because 100% match with on truck scan date
        df = df.drop("pickup date", axis=1)

    

    return df

# %% [markdown]
# ### Checks for cleaning function

# %% [markdown]
# #### Orders data

# %%
df_orders_1 = data_cleaning(df_orders,"orders")
df_orders_1
# Out:
#             order id order date ship mode customer id country/region  \
# 0     CA-2019-121755 2019-01-16  Standard    EH-13945  United States
# 1     CA-2019-118255 2019-03-11   Express    ON-18715  United States
# 2     CA-2019-169194 2019-06-20  Standard    LH-16900  United States
# 3     CA-2019-111682 2019-06-17   Express    TB-21055  United States
# 4     CA-2018-135545 2018-11-24  Standard    KM-16720  United States
# ...              ...        ...       ...         ...            ...
# 9979  CA-2019-146913 2019-10-31  Standard    SF-20965  United States
# 9980  US-2017-114377 2017-11-05   Express    BG-11035  United States
# 9984  CA-2020-107209 2020-07-27  Standard    JW-15955  United States
# 9986  US-2020-152842 2020-07-16  Standard    NF-18385  United States
# 9988  CA-2019-122581 2019-08-21  Standard    JK-15370  United States
#
#                city           state  postal code   region
# 0       Los Angeles      California      90049.0     West
# 1             Eagan       Minnesota      55122.0  Central
# 2             Dover        Delaware      19901.0     East
# 3              Troy        New York      12180.0     East
# 4       Los Angeles      California      90004.0     West
# ...             ...             ...          ...      ...
# 9979  San Francisco      California      94109.0     West
# 9980        Hampton        Virginia      23666.0    South
# 9984        Raleigh  North Carolina      27604.0    South
# 9986      Charlotte  North Carolina      28205.0    South
# 9988  New York City        New York      10035.0     East
#
# [5009 rows x 9 columns]

# %%
df_orders_1.duplicated().value_counts()
# Out:
# False    5009
# Name: count, dtype: int64

# %%
df_orders_1["order id"].nunique()
# Out:
# 5009

# %%
df_orders_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5009 entries, 0 to 9988
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order id        5009 non-null   object
#  1   order date      5009 non-null   datetime64[ns]
#  2   ship mode       5009 non-null   object
#  3   customer id     5009 non-null   object
#  4   country/region  5009 non-null   object
#  5   city            5009 non-null   object
#  6   state           5009 non-null   object
#  7   postal code     5003 non-null   float64
#  8   region          5009 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 391.3+ KB

# %% [markdown]
# #### Campaign data

# %%
df_campaign_1 = data_cleaning(df_campaign,"campaign")
df_campaign_1
# Out:
#            order id arrival scan date
# 0    CA-2019-109666        2019-05-03
# 1    CA-2019-138933        2019-05-03
# 2    CA-2019-130001        2019-05-03
# 3    CA-2019-113061        2019-05-06
# 4    CA-2019-162138        2019-05-06
# ..              ...               ...
# 328  CA-2020-129707        2020-05-08
# 329  CA-2020-125381        2020-05-08
# 330  CA-2020-141733        2020-05-15
# 331  US-2020-104451        2020-05-15
# 332  US-2020-139647        2020-05-15
#
# [333 rows x 2 columns]

# %%
df_campaign_1.duplicated().value_counts()
# Out:
# False    333
# Name: count, dtype: int64

# %%
df_campaign_1["order id"].nunique()
# Out:
# 333

# %%
df_campaign_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order id           333 non-null    object
#  1   arrival scan date  333 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 5.3+ KB

# %% [markdown]
# #### Order process data

# %%
df_order_process_1 = data_cleaning(df_order_process,"order_process")
df_order_process_1
# Out:
#             order id on truck scan date
# 0     CA-2019-125206         2019-01-07
# 1     CA-2019-160304         2019-01-09
# 3     US-2019-116365         2019-01-09
# 6     CA-2019-105207         2019-01-09
# 8     CA-2019-158211         2019-01-09
# ...              ...                ...
# 5890  CA-2020-130631         2021-01-06
# 5892  CA-2020-126221         2021-01-06
# 5893  CA-2020-143259         2021-01-06
# 5896  CA-2020-115427         2021-01-06
# 5898  CA-2020-156720         2021-01-06
#
# [3002 rows x 2 columns]

# %%
df_order_process_1.duplicated().value_counts()
# Out:
# False    3002
# Name: count, dtype: int64

# %%
df_order_process_1["order id"].duplicated().value_counts()
# Out:
# order id
# False    3002
# Name: count, dtype: int64

# %%
df_order_process_1.drop_duplicates("order id")
# Out:
#             order id on truck scan date
# 0     CA-2019-125206         2019-01-07
# 1     CA-2019-160304         2019-01-09
# 3     US-2019-116365         2019-01-09
# 6     CA-2019-105207         2019-01-09
# 8     CA-2019-158211         2019-01-09
# ...              ...                ...
# 5890  CA-2020-130631         2021-01-06
# 5892  CA-2020-126221         2021-01-06
# 5893  CA-2020-143259         2021-01-06
# 5896  CA-2020-115427         2021-01-06
# 5898  CA-2020-156720         2021-01-06
#
# [3002 rows x 2 columns]

# %%
duplicates = df_order_process_1[df_order_process_1["order id"].duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [order id, on truck scan date]
# Index: []

# %%
df_order_process_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3002 entries, 0 to 5898
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order id            3002 non-null   object
#  1   on truck scan date  3002 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 70.4+ KB

# %% [markdown]
# #### Intern data

# %%
df_interndata_1 = data_cleaning(df_interndata,"intern")
df_interndata_1
# Out:
#            order id ready to ship date
# 0    CA-2019-116540         2019-09-02
# 2    CA-2019-129847         2019-09-04
# 3    CA-2019-129630         2019-09-04
# 4    CA-2019-106278         2019-09-05
# 5    CA-2019-158099         2019-09-05
# ..              ...                ...
# 283  US-2020-165456         2020-12-03
# 284  US-2020-110576         2020-12-04
# 285  CA-2020-105333         2020-12-04
# 288  CA-2020-119305         2020-12-04
# 289  CA-2020-142090         2020-12-07
#
# [204 rows x 2 columns]

# %%
df_interndata_1.duplicated().value_counts()
# Out:
# False    204
# Name: count, dtype: int64

# %%
df_interndata_1["order id"].duplicated().value_counts()
# Out:
# order id
# False    204
# Name: count, dtype: int64

# %%
df_interndata_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 204 entries, 0 to 289
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order id            204 non-null    object
#  1   ready to ship date  204 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# #### Truck scan vs intern scan

# %%
merged_truck = df_order_process_1.merge(df_interndata_1, on="order id", how="outer")
# merged_truck = merged_truck[["order id","on truck scan date","pickup date"]].dropna()
merged_truck
# Out:
#             order id on truck scan date ready to ship date
# 0     CA-2019-100041         2019-11-27                NaT
# 1     CA-2019-100083         2019-12-04                NaT
# 2     CA-2019-100153         2019-12-18                NaT
# 3     CA-2019-100202         2020-01-08                NaT
# 4     CA-2019-100244         2019-09-25         2019-09-24
# ...              ...                ...                ...
# 2997  US-2020-168802         2020-11-12         2020-11-09
# 2998  US-2020-169320         2020-07-29                NaT
# 2999  US-2020-169488         2020-09-09                NaT
# 3000  US-2020-169502         2020-09-02                NaT
# 3001  US-2020-169551         2020-07-10                NaT
#
# [3002 rows x 3 columns]

# %%
# merged_truck["diff"] = merged_truck["on truck scan date"] - merged_truck["pickup date"]
# merged_truck

# %% [markdown]
# #### Order dates & shipping methods

# %%
merged_op = df_orders_1.merge(df_order_process_1, on="order id", how="outer").dropna()

# %%
# merged_op[["order id","order date_x","ship mode_x","order date_y","ship mode_y"]]
# merged_op["date_diff"] = merged_op["order date_x"]-merged_op["order date_y"]
# merged_op["date_diff"].value_counts()

# %%
# merged_op

# %%
# merged_op[["order id","ship mode_x","ship mode_y"]]

# %%
# merged_op["ship mode_x"].value_counts()

# %%
# merged_op["ship mode_y"].value_counts()

# %%
#merged_op["ship mode_x"] = merged_op["ship mode_x"].str.replace(" Class","")
#merged_op["ship mode_y"] = merged_op["ship mode_y"].str.replace(" Processing","")
#merged_op["ship mode_x"] = merged_op["ship mode_x"].str.replace("Second","Standard")
#merged_op["ship mode_x"] = merged_op["ship mode_x"].str.replace("First","Express")

# %%
#merged_op[["order id","ship mode_x","ship mode_y"]]

# %%
#merged_op['match'] = merged_op['ship mode_x'] == merged_op['ship mode_y']
#merged_op['match'].value_counts()

# %% [markdown]
# ## Cleaned dataframes

# %%
df_orders_cleaned = data_cleaning(df_orders,"orders")
df_campaign_cleaned = data_cleaning(df_campaign,"campaign")
df_order_process_cleaned = data_cleaning(df_order_process,"order_process")
df_interndata_cleaned = data_cleaning(df_interndata,"intern")

# %%
df_orders_cleaned
# Out:
#             order id order date ship mode customer id country/region  \
# 0     CA-2019-121755 2019-01-16  Standard    EH-13945  United States
# 1     CA-2019-118255 2019-03-11   Express    ON-18715  United States
# 2     CA-2019-169194 2019-06-20  Standard    LH-16900  United States
# 3     CA-2019-111682 2019-06-17   Express    TB-21055  United States
# 4     CA-2018-135545 2018-11-24  Standard    KM-16720  United States
# ...              ...        ...       ...         ...            ...
# 9979  CA-2019-146913 2019-10-31  Standard    SF-20965  United States
# 9980  US-2017-114377 2017-11-05   Express    BG-11035  United States
# 9984  CA-2020-107209 2020-07-27  Standard    JW-15955  United States
# 9986  US-2020-152842 2020-07-16  Standard    NF-18385  United States
# 9988  CA-2019-122581 2019-08-21  Standard    JK-15370  United States
#
#                city           state  postal code   region
# 0       Los Angeles      California      90049.0     West
# 1             Eagan       Minnesota      55122.0  Central
# 2             Dover        Delaware      19901.0     East
# 3              Troy        New York      12180.0     East
# 4       Los Angeles      California      90004.0     West
# ...             ...             ...          ...      ...
# 9979  San Francisco      California      94109.0     West
# 9980        Hampton        Virginia      23666.0    South
# 9984        Raleigh  North Carolina      27604.0    South
# 9986      Charlotte  North Carolina      28205.0    South
# 9988  New York City        New York      10035.0     East
#
# [5009 rows x 9 columns]

# %%
df_campaign_cleaned
# Out:
#            order id arrival scan date
# 0    CA-2019-109666        2019-05-03
# 1    CA-2019-138933        2019-05-03
# 2    CA-2019-130001        2019-05-03
# 3    CA-2019-113061        2019-05-06
# 4    CA-2019-162138        2019-05-06
# ..              ...               ...
# 328  CA-2020-129707        2020-05-08
# 329  CA-2020-125381        2020-05-08
# 330  CA-2020-141733        2020-05-15
# 331  US-2020-104451        2020-05-15
# 332  US-2020-139647        2020-05-15
#
# [333 rows x 2 columns]

# %%
df_order_process_cleaned
# Out:
#             order id on truck scan date
# 0     CA-2019-125206         2019-01-07
# 1     CA-2019-160304         2019-01-09
# 3     US-2019-116365         2019-01-09
# 6     CA-2019-105207         2019-01-09
# 8     CA-2019-158211         2019-01-09
# ...              ...                ...
# 5890  CA-2020-130631         2021-01-06
# 5892  CA-2020-126221         2021-01-06
# 5893  CA-2020-143259         2021-01-06
# 5896  CA-2020-115427         2021-01-06
# 5898  CA-2020-156720         2021-01-06
#
# [3002 rows x 2 columns]

# %%
df_interndata_cleaned
# Out:
#            order id ready to ship date
# 0    CA-2019-116540         2019-09-02
# 2    CA-2019-129847         2019-09-04
# 3    CA-2019-129630         2019-09-04
# 4    CA-2019-106278         2019-09-05
# 5    CA-2019-158099         2019-09-05
# ..              ...                ...
# 283  US-2020-165456         2020-12-03
# 284  US-2020-110576         2020-12-04
# 285  CA-2020-105333         2020-12-04
# 288  CA-2020-119305         2020-12-04
# 289  CA-2020-142090         2020-12-07
#
# [204 rows x 2 columns]

# %% [markdown]
# ## Metrics

# %% [markdown]
# ### o_date_2_processed

# %%
merged_metric_1 = df_orders_cleaned.merge(df_interndata_cleaned, on="order id", how="outer").dropna()
merged_metric_1
# Out:
#             order id order date ship mode customer id country/region  \
# 1703  CA-2019-100244 2019-09-20  Standard    GM-14695  United States
# 1711  CA-2019-100944 2019-09-24  Standard    EH-13765  United States
# 1740  CA-2019-102162 2019-09-11  Standard    JF-15565  United States
# 1747  CA-2019-102932 2019-09-19  Standard    SD-20485  United States
# 1748  CA-2019-102981 2019-09-06  Standard    MO-17500  United States
# ...              ...        ...       ...         ...            ...
# 4984  US-2020-163790 2020-11-02  Standard    NL-18310  United States
# 4987  US-2020-165344 2020-11-13   Express    SB-20290  United States
# 4989  US-2020-165456 2020-11-30   Express    TB-21625  United States
# 5001  US-2020-168116 2020-11-04   Express    GT-14635  United States
# 5004  US-2020-168802 2020-11-03  Standard    JO-15145  United States
#
#                city           state  postal code region ready to ship date
# 1703  San Francisco      California      94122.0   West         2019-09-24
# 1711    Los Angeles      California      90049.0   West         2019-09-30
# 1740   Newport News        Virginia      23602.0  South         2019-09-16
# 1747         Orange      New Jersey       7050.0   East         2019-09-23
# 1748  New York City        New York      10035.0   East         2019-09-09
# ...             ...             ...          ...    ...                ...
# 4984       Danville      California      94526.0   West         2020-11-04
# 4987    Springfield            Ohio      45503.0   East         2020-11-16
# 4989   Philadelphia    Pennsylvania      19134.0   East         2020-12-03
# 5001     Burlington  North Carolina      27217.0  South         2020-11-04
# 5004        Seattle      Washington      98103.0   West         2020-11-09
#
# [204 rows x 10 columns]

# %%
merged_metric_1["date_diff"] = merged_metric_1["ready to ship date"]-merged_metric_1["order date"]
merged_metric_1
# Out:
#             order id order date ship mode customer id country/region  \
# 1703  CA-2019-100244 2019-09-20  Standard    GM-14695  United States
# 1711  CA-2019-100944 2019-09-24  Standard    EH-13765  United States
# 1740  CA-2019-102162 2019-09-11  Standard    JF-15565  United States
# 1747  CA-2019-102932 2019-09-19  Standard    SD-20485  United States
# 1748  CA-2019-102981 2019-09-06  Standard    MO-17500  United States
# ...              ...        ...       ...         ...            ...
# 4984  US-2020-163790 2020-11-02  Standard    NL-18310  United States
# 4987  US-2020-165344 2020-11-13   Express    SB-20290  United States
# 4989  US-2020-165456 2020-11-30   Express    TB-21625  United States
# 5001  US-2020-168116 2020-11-04   Express    GT-14635  United States
# 5004  US-2020-168802 2020-11-03  Standard    JO-15145  United States
#
#                city           state  postal code region ready to ship date  \
# 1703  San Francisco      California      94122.0   West         2019-09-24
# 1711    Los Angeles      California      90049.0   West         2019-09-30
# 1740   Newport News        Virginia      23602.0  South         2019-09-16
# 1747         Orange      New Jersey       7050.0   East         2019-09-23
# 1748  New York City        New York      10035.0   East         2019-09-09
# ...             ...             ...          ...    ...                ...
# 4984       Danville      California      94526.0   West         2020-11-04
# 4987    Springfield            Ohio      45503.0   East         2020-11-16
# 4989   Philadelphia    Pennsylvania      19134.0   East         2020-12-03
# 5001     Burlington  North Carolina      27217.0  South         2020-11-04
# 5004        Seattle      Washington      98103.0   West         2020-11-09
#
#      date_diff
# 1703    4 days
# 1711    6 days
# 1740    5 days
# 1747    4 days
# 1748    3 days
# ...        ...
# 4984    2 days
# 4987    3 days
# 4989    3 days
# 5001    0 days
# 5004    6 days
#
# [204 rows x 11 columns]

# %%
merged_metric_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 204 entries, 1703 to 5004
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order id            204 non-null    object
#  1   order date          204 non-null    datetime64[ns]
#  2   ship mode           204 non-null    object
#  3   customer id         204 non-null    object
#  4   country/region      204 non-null    object
#  5   city                204 non-null    object
#  6   state               204 non-null    object
#  7   postal code         204 non-null    float64
#  8   region              204 non-null    object
#  9   ready to ship date  204 non-null    datetime64[ns]
#  10  date_diff           204 non-null    timedelta64[ns]
# dtypes: datetime64[ns](2), float64(1), object(7), timedelta64[ns](1)
# memory usage: 19.1+ KB

# %%
merged_metric_1["date_diff_days"] = merged_metric_1["date_diff"].dt.days

# %%
merged_metric_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 204 entries, 1703 to 5004
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order id            204 non-null    object
#  1   order date          204 non-null    datetime64[ns]
#  2   ship mode           204 non-null    object
#  3   customer id         204 non-null    object
#  4   country/region      204 non-null    object
#  5   city                204 non-null    object
#  6   state               204 non-null    object
#  7   postal code         204 non-null    float64
#  8   region              204 non-null    object
#  9   ready to ship date  204 non-null    datetime64[ns]
#  10  date_diff           204 non-null    timedelta64[ns]
#  11  date_diff_days      204 non-null    int64
# dtypes: datetime64[ns](2), float64(1), int64(1), object(7), timedelta64[ns](1)
# memory usage: 20.7+ KB

# %%
# 1. Distribution of date_diff
plt.figure(figsize=(8,5))
plt.hist(merged_metric_1["date_diff_days"], edgecolor="black")
plt.title("Distribution of date difference")
plt.xlabel("Days between order and ready to ship")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### WEEKDAYS

# %%
# Order weekday (0=Monday, 6=Sunday)
merged_metric_1["order_weekday"] = merged_metric_1["order date"].dt.day_name()

# Ready-to-ship weekday
merged_metric_1["ship_weekday"] = merged_metric_1["ready to ship date"].dt.day_name()

# %%
merged_metric_1
# Out:
#             order id order date ship mode customer id country/region  \
# 1703  CA-2019-100244 2019-09-20  Standard    GM-14695  United States
# 1711  CA-2019-100944 2019-09-24  Standard    EH-13765  United States
# 1740  CA-2019-102162 2019-09-11  Standard    JF-15565  United States
# 1747  CA-2019-102932 2019-09-19  Standard    SD-20485  United States
# 1748  CA-2019-102981 2019-09-06  Standard    MO-17500  United States
# ...              ...        ...       ...         ...            ...
# 4984  US-2020-163790 2020-11-02  Standard    NL-18310  United States
# 4987  US-2020-165344 2020-11-13   Express    SB-20290  United States
# 4989  US-2020-165456 2020-11-30   Express    TB-21625  United States
# 5001  US-2020-168116 2020-11-04   Express    GT-14635  United States
# 5004  US-2020-168802 2020-11-03  Standard    JO-15145  United States
#
#                city           state  postal code region ready to ship date  \
# 1703  San Francisco      California      94122.0   West         2019-09-24
# 1711    Los Angeles      California      90049.0   West         2019-09-30
# 1740   Newport News        Virginia      23602.0  South         2019-09-16
# 1747         Orange      New Jersey       7050.0   East         2019-09-23
# 1748  New York City        New York      10035.0   East         2019-09-09
# ...             ...             ...          ...    ...                ...
# 4984       Danville      California      94526.0   West         2020-11-04
# 4987    Springfield            Ohio      45503.0   East         2020-11-16
# 4989   Philadelphia    Pennsylvania      19134.0   East         2020-12-03
# 5001     Burlington  North Carolina      27217.0  South         2020-11-04
# 5004        Seattle      Washington      98103.0   West         2020-11-09
#
#      date_diff  date_diff_days order_weekday ship_weekday
# 1703    4 days               4        Friday      Tuesday
# 1711    6 days               6       Tuesday       Monday
# 1740    5 days               5     Wednesday       Monday
# 1747    4 days               4      Thursday       Monday
# 1748    3 days               3        Friday       Monday
# ...        ...             ...           ...          ...
# 4984    2 days               2        Monday    Wednesday
# 4987    3 days               3        Friday       Monday
# 4989    3 days               3        Monday     Thursday
# 5001    0 days               0     Wednesday    Wednesday
# 5004    6 days               6       Tuesday       Monday
#
# [204 rows x 14 columns]

# %%
orders_by_day = merged_metric_1["order_weekday"].value_counts()
ship_by_day = merged_metric_1["ship_weekday"].value_counts()
avg_delay_by_day = merged_metric_1.groupby("order_weekday")["date_diff_days"].mean()

# %%
# 1 Order date by weekdays

orders_by_day = merged_metric_1["order_weekday"].value_counts().reindex(
    ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
)

orders_by_day.plot(kind="bar", figsize=(8,5), color="skyblue", edgecolor="black")
plt.title("Orders by Weekday")
plt.ylabel("Number of Orders")
plt.show()

# %%
# 2 ready to Ship date by Weekdays

ship_by_day = merged_metric_1["ship_weekday"].value_counts().reindex(
    ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
)

ship_by_day.plot(kind="bar", figsize=(8,5), color="lightgreen", edgecolor="black")
plt.title("Ready-to-Ship by Weekday")
plt.ylabel("Number of Orders")
plt.show()

# %%
# 3 Average delay by Weekdays

avg_delay_by_day = merged_metric_1.groupby("order_weekday")["date_diff_days"].mean().reindex(
    ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
)

avg_delay_by_day.plot(kind="bar", figsize=(8,5), color="orange", edgecolor="black")
plt.title("Average Time by Order Weekday")
plt.ylabel("Average Time (days)")
plt.show()

# %%
merged_metric_1["ship mode"] = merged_metric_1["ship mode"].str.replace(" Class","")
merged_metric_1["ship mode"] = merged_metric_1["ship mode"].str.replace("Second","Standard")
merged_metric_1["ship mode"] = merged_metric_1["ship mode"].str.replace("First","Express")

# %%
avg_diff_by_mode = merged_metric_1.groupby("ship mode")["date_diff_days"].mean().reset_index().round(2)
avg_diff_by_mode
# Out:
#   ship mode  date_diff_days
# 0   Express            2.04
# 1  Standard            4.93

# %%
# actual average delay for Standard
actual_std = (
    merged_metric_1[merged_metric_1["ship mode"]=="Standard"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
)

# expected values
expected_data = {
    "order_weekday": ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],
    "expected_delay": [2,2,2,2,4,4,3]
}
expected_df = pd.DataFrame(expected_data).set_index("order_weekday")

# align both (reindex to weekday order)
weekday_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
actual_std = actual_std.reindex(weekday_order)
expected_df = expected_df.reindex(weekday_order)

# combine
comparison = pd.DataFrame({
    "Actual (Standard)": actual_std,
    "Expected (Standard)": expected_df["expected_delay"]
})

# plot
comparison.plot(kind="bar", figsize=(12,6))
plt.title("Standard: Ordered to (ready to be ship) Duration Time: Actual vs Expected")
plt.ylabel("Average Duration Time (days)")
plt.xlabel("Order Weekday")
plt.xticks(rotation=45)
plt.legend(title="Series")
plt.show()

# %%
# actual average delay for Express
actual_exp = (
    merged_metric_1[merged_metric_1["ship mode"]=="Express"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
)

# expected values
expected_data = {
    "order_weekday": ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],
    "expected_delay": [2,2,2,2,4,4,3]
}
expected_df = pd.DataFrame(expected_data).set_index("order_weekday")

# align both (reindex to weekday order)
weekday_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
actual_exp = actual_exp.reindex(weekday_order)
expected_df = expected_df.reindex(weekday_order)

# combine into comparison table
comparison = pd.DataFrame({
    "Actual (Express)": actual_exp,
    "Expected (Express)": expected_df["expected_delay"]
})

# plot
comparison.plot(kind="bar", figsize=(12,6))
plt.title("Express: ordered to (ready to be ship) Duration Time: Actual vs Expected")
plt.ylabel("Average Time (days)")
plt.xlabel("Order Weekday")
plt.xticks(rotation=45)
plt.legend(title="Series")
plt.show()

# %%
# expected values (same for express & standard)
expected_data = {
    "order_weekday": ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],
    "Expected": [2,2,2,2,4,4,3]
}
expected_df = pd.DataFrame(expected_data).set_index("order_weekday")

# weekday order
weekday_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]

# actual average delay for Standard
actual_std = (
    merged_metric_1[merged_metric_1["ship mode"]=="Standard"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
    .reindex(weekday_order)
)

# actual average delay for Express
actual_exp = (
    merged_metric_1[merged_metric_1["ship mode"]=="Express"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
    .reindex(weekday_order)
)

# combine into one DataFrame
comparison = pd.DataFrame({
    "Expected": expected_df["Expected"],
    "Actual (Standard)": actual_std,
    "Actual (Express)": actual_exp
})

# plot
comparison.plot(kind="bar", figsize=(12,6))
plt.title("Ordered to Ready-to-Ship Duration: Expected vs Actual (Standard & Express)")
plt.ylabel("Average Duration Time (days)")
plt.xlabel("Order Weekday")
plt.xticks(rotation=0)
plt.legend(title="Series")
plt.show()

# %%
# expected values (same for express & standard)
expected_data = {
    "order_weekday": ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],
    "Expected": [2,2,2,2,4,4,3]
}
expected_df = pd.DataFrame(expected_data).set_index("order_weekday")

# weekday order
weekday_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]

# actual average delay for Standard
actual_std = (
    merged_metric_1[merged_metric_1["ship mode"]=="Standard"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
    .reindex(weekday_order)
)

# actual average delay for Express
actual_exp = (
    merged_metric_1[merged_metric_1["ship mode"]=="Express"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
    .reindex(weekday_order)
)

# combine into one DataFrame
comparison = pd.DataFrame({
    "Expected": expected_df["Expected"],
    "Actual (Standard)": actual_std,
    "Actual (Express)": actual_exp
})

# plot and add value labels
ax = comparison.plot(kind="bar", figsize=(12,6))
plt.title("Ordered to Ready-to-Ship Duration: Expected vs Actual (Standard & Express)")
plt.ylabel("Average Duration Time (days)")
plt.xlabel("Order Weekday")
plt.xticks(rotation=0)
plt.legend(title="Series")

# add labels to each bar
for container in ax.containers:
    ax.bar_label(container, fmt="%.1f", label_type="edge", padding=2)

plt.show()

# %% [markdown]
# ### o_processes_2_truck

# %% [markdown]
# #### Data

# %%
df_processed = df_interndata_cleaned.copy()
df_processed["ready to ship date_weekday"] = df_processed["ready to ship date"].dt.dayofweek
df_processed
# Out:
#            order id ready to ship date  ready to ship date_weekday
# 0    CA-2019-116540         2019-09-02                           0
# 2    CA-2019-129847         2019-09-04                           2
# 3    CA-2019-129630         2019-09-04                           2
# 4    CA-2019-106278         2019-09-05                           3
# 5    CA-2019-158099         2019-09-05                           3
# ..              ...                ...                         ...
# 283  US-2020-165456         2020-12-03                           3
# 284  US-2020-110576         2020-12-04                           4
# 285  CA-2020-105333         2020-12-04                           4
# 288  CA-2020-119305         2020-12-04                           4
# 289  CA-2020-142090         2020-12-07                           0
#
# [204 rows x 3 columns]

# %%
df_processed["ready to ship date_weekday"].value_counts()
# Out:
# ready to ship date_weekday
# 0    93
# 4    31
# 1    29
# 3    28
# 2    23
# Name: count, dtype: int64

# %%
# ready to ship date only Mo - Fr checked!

# %%
df_processed_x_truck = df_order_process_cleaned.merge(df_processed, on="order id",how="inner")
df_processed_x_truck
# Out:
#            order id on truck scan date ready to ship date  \
# 0    CA-2019-116540         2019-09-03         2019-09-02
# 1    CA-2019-129847         2019-09-04         2019-09-04
# 2    CA-2019-129630         2019-09-04         2019-09-04
# 3    CA-2019-158099         2019-09-06         2019-09-05
# 4    CA-2019-132143         2019-09-06         2019-09-05
# ..              ...                ...                ...
# 199  CA-2020-159506         2020-12-04         2020-12-02
# 200  US-2020-110576         2020-12-07         2020-12-04
# 201  CA-2020-119305         2020-12-07         2020-12-04
# 202  CA-2020-105333         2020-12-07         2020-12-04
# 203  CA-2020-142090         2020-12-09         2020-12-07
#
#      ready to ship date_weekday
# 0                             0
# 1                             2
# 2                             2
# 3                             3
# 4                             3
# ..                          ...
# 199                           2
# 200                           4
# 201                           4
# 202                           4
# 203                           0
#
# [204 rows x 4 columns]

# %%
df_processed_x_truck_smode = df_processed_x_truck.merge(df_orders_cleaned, on="order id", how="inner")
df_processed_x_truck_smode = df_processed_x_truck_smode[["order id", "on truck scan date", "ready to ship date", "ready to ship date_weekday","ship mode","order date"]]
df_processed_x_truck_smode["o_processed_2_truck_actual"] = df_processed_x_truck_smode["on truck scan date"] - df_processed_x_truck_smode["ready to ship date"]
df_processed_x_truck_smode["o_processed_2_truck_actual"] = df_processed_x_truck_smode["o_processed_2_truck_actual"].dt.days
df_processed_x_truck_smode
# Out:
#            order id on truck scan date ready to ship date  \
# 0    CA-2019-116540         2019-09-03         2019-09-02
# 1    CA-2019-129847         2019-09-04         2019-09-04
# 2    CA-2019-129630         2019-09-04         2019-09-04
# 3    CA-2019-158099         2019-09-06         2019-09-05
# 4    CA-2019-132143         2019-09-06         2019-09-05
# ..              ...                ...                ...
# 199  CA-2020-159506         2020-12-04         2020-12-02
# 200  US-2020-110576         2020-12-07         2020-12-04
# 201  CA-2020-119305         2020-12-07         2020-12-04
# 202  CA-2020-105333         2020-12-07         2020-12-04
# 203  CA-2020-142090         2020-12-09         2020-12-07
#
#      ready to ship date_weekday ship mode order date  \
# 0                             0   Express 2019-09-02
# 1                             2   Express 2019-09-02
# 2                             2   Express 2019-09-04
# 3                             3   Express 2019-09-03
# 4                             3   Express 2019-09-03
# ..                          ...       ...        ...
# 199                           2  Standard 2020-11-27
# 200                           4  Standard 2020-11-28
# 201                           4  Standard 2020-11-30
# 202                           4  Standard 2020-11-30
# 203                           0  Standard 2020-11-30
#
#      o_processed_2_truck_actual
# 0                             1
# 1                             0
# 2                             0
# 3                             1
# 4                             1
# ..                          ...
# 199                           2
# 200                           3
# 201                           3
# 202                           3
# 203                           2
#
# [204 rows x 7 columns]

# %%
df_processed_x_truck_smode["order date_weekday"] = df_processed_x_truck_smode["order date"].dt.day_name()
df_processed_x_truck_smode
# Out:
#            order id on truck scan date ready to ship date  \
# 0    CA-2019-116540         2019-09-03         2019-09-02
# 1    CA-2019-129847         2019-09-04         2019-09-04
# 2    CA-2019-129630         2019-09-04         2019-09-04
# 3    CA-2019-158099         2019-09-06         2019-09-05
# 4    CA-2019-132143         2019-09-06         2019-09-05
# ..              ...                ...                ...
# 199  CA-2020-159506         2020-12-04         2020-12-02
# 200  US-2020-110576         2020-12-07         2020-12-04
# 201  CA-2020-119305         2020-12-07         2020-12-04
# 202  CA-2020-105333         2020-12-07         2020-12-04
# 203  CA-2020-142090         2020-12-09         2020-12-07
#
#      ready to ship date_weekday ship mode order date  \
# 0                             0   Express 2019-09-02
# 1                             2   Express 2019-09-02
# 2                             2   Express 2019-09-04
# 3                             3   Express 2019-09-03
# 4                             3   Express 2019-09-03
# ..                          ...       ...        ...
# 199                           2  Standard 2020-11-27
# 200                           4  Standard 2020-11-28
# 201                           4  Standard 2020-11-30
# 202                           4  Standard 2020-11-30
# 203                           0  Standard 2020-11-30
#
#      o_processed_2_truck_actual order date_weekday
# 0                             1             Monday
# 1                             0             Monday
# 2                             0          Wednesday
# 3                             1            Tuesday
# 4                             1            Tuesday
# ..                          ...                ...
# 199                           2             Friday
# 200                           3           Saturday
# 201                           3             Monday
# 202                           3             Monday
# 203                           2             Monday
#
# [204 rows x 8 columns]

# %%
df_processed_x_truck_smode.groupby("ship mode")[["o_processed_2_truck_actual"]].agg(["mean","max","min"])
# Out:
#           o_processed_2_truck_actual
#                                 mean max min
# ship mode
# Express                     0.396226   2   0
# Standard                    1.986755   3   1

# %%
graph_1 = df_processed_x_truck_smode.groupby("ship mode")[["o_processed_2_truck_actual"]].mean().reset_index()
graph_1
# Out:
#   ship mode  o_processed_2_truck_actual
# 0   Express                    0.396226
# 1  Standard                    1.986755

# %%
graph_1["o_processed_2_truck_plan"] = {0:0,1:1}
graph_1
# Out:
#   ship mode  o_processed_2_truck_actual  o_processed_2_truck_plan
# 0   Express                    0.396226                         0
# 1  Standard                    1.986755                         1

# %%
# format for plot
graph_1 = pd.melt(graph_1,
    id_vars=["ship mode"],
    value_vars=["o_processed_2_truck_actual", "o_processed_2_truck_plan"],
    var_name="data type",
    value_name="days")

# renaming data type
graph_1["data type"] = graph_1["data type"].map({
    "o_processed_2_truck_actual": "Actual",
    "o_processed_2_truck_plan": "Plan"})

graph_1
# Out:
#   ship mode data type      days
# 0   Express    Actual  0.396226
# 1  Standard    Actual  1.986755
# 2   Express      Plan  0.000000
# 3  Standard      Plan  1.000000

# %%
graph_2 = df_processed_x_truck_smode.groupby(["ship mode","order date_weekday"])[["o_processed_2_truck_actual"]].mean().reset_index()
graph_2
# Out:
#    ship mode order date_weekday  o_processed_2_truck_actual
# 0    Express             Friday                    0.000000
# 1    Express             Monday                    0.500000
# 2    Express           Saturday                    0.500000
# 3    Express           Thursday                    0.200000
# 4    Express            Tuesday                    0.846154
# 5    Express          Wednesday                    0.090909
# 6   Standard             Friday                    1.812500
# 7   Standard             Monday                    2.280000
# 8   Standard           Saturday                    2.777778
# 9   Standard             Sunday                    1.666667
# 10  Standard           Thursday                    1.857143
# 11  Standard            Tuesday                    1.828571
# 12  Standard          Wednesday                    2.000000

# %%
# no sunday for express?

# %%
graph_2["identifyer"]=graph_2["ship mode"]+graph_2["order date_weekday"]
graph_2
# Out:
#    ship mode order date_weekday  o_processed_2_truck_actual         identifyer
# 0    Express             Friday                    0.000000      ExpressFriday
# 1    Express             Monday                    0.500000      ExpressMonday
# 2    Express           Saturday                    0.500000    ExpressSaturday
# 3    Express           Thursday                    0.200000    ExpressThursday
# 4    Express            Tuesday                    0.846154     ExpressTuesday
# 5    Express          Wednesday                    0.090909   ExpressWednesday
# 6   Standard             Friday                    1.812500     StandardFriday
# 7   Standard             Monday                    2.280000     StandardMonday
# 8   Standard           Saturday                    2.777778   StandardSaturday
# 9   Standard             Sunday                    1.666667     StandardSunday
# 10  Standard           Thursday                    1.857143   StandardThursday
# 11  Standard            Tuesday                    1.828571    StandardTuesday
# 12  Standard          Wednesday                    2.000000  StandardWednesday

# %%
plan_values_dict = {"ExpressMonday":1,
                    "ExpressTuesday":0,
                    "ExpressWednesday":1,
                    "ExpressThursday":0,
                    "ExpressFriday":0,
                    "ExpressSaturday":1,
                    "ExpressSunday":1,
                    "StandardMonday":1,
                    "StandardTuesday":2,
                    "StandardWednesday":1,
                    "StandardThursday":3,
                    "StandardFriday":2,
                    "StandardSaturday":1,
                    "StandardSunday":1
                    }

# %%
graph_2["o_processed_2_truck_plan"] = graph_2["identifyer"].map(plan_values_dict)
graph_2 = graph_2.drop("identifyer",axis=1)
graph_2
# Out:
#    ship mode order date_weekday  o_processed_2_truck_actual  \
# 0    Express             Friday                    0.000000
# 1    Express             Monday                    0.500000
# 2    Express           Saturday                    0.500000
# 3    Express           Thursday                    0.200000
# 4    Express            Tuesday                    0.846154
# 5    Express          Wednesday                    0.090909
# 6   Standard             Friday                    1.812500
# 7   Standard             Monday                    2.280000
# 8   Standard           Saturday                    2.777778
# 9   Standard             Sunday                    1.666667
# 10  Standard           Thursday                    1.857143
# 11  Standard            Tuesday                    1.828571
# 12  Standard          Wednesday                    2.000000
#
#     o_processed_2_truck_plan
# 0                          0
# 1                          1
# 2                          1
# 3                          0
# 4                          0
# 5                          1
# 6                          2
# 7                          1
# 8                          1
# 9                          1
# 10                         3
# 11                         2
# 12                         1

# %%
# format for plot
graph_2 = pd.melt(graph_2,
    id_vars=["ship mode","order date_weekday"],
    value_vars=["o_processed_2_truck_actual", "o_processed_2_truck_plan"],
    var_name="data type",
    value_name="days")

# renaming data type
graph_2["data type"] = graph_2["data type"].map({
    "o_processed_2_truck_actual": "Actual",
    "o_processed_2_truck_plan": "Plan"})

graph_2
# Out:
#    ship mode order date_weekday data type      days
# 0    Express             Friday    Actual  0.000000
# 1    Express             Monday    Actual  0.500000
# 2    Express           Saturday    Actual  0.500000
# 3    Express           Thursday    Actual  0.200000
# 4    Express            Tuesday    Actual  0.846154
# 5    Express          Wednesday    Actual  0.090909
# 6   Standard             Friday    Actual  1.812500
# 7   Standard             Monday    Actual  2.280000
# 8   Standard           Saturday    Actual  2.777778
# 9   Standard             Sunday    Actual  1.666667
# 10  Standard           Thursday    Actual  1.857143
# 11  Standard            Tuesday    Actual  1.828571
# 12  Standard          Wednesday    Actual  2.000000
# 13   Express             Friday      Plan  0.000000
# 14   Express             Monday      Plan  1.000000
# 15   Express           Saturday      Plan  1.000000
# 16   Express           Thursday      Plan  0.000000
# 17   Express            Tuesday      Plan  0.000000
# 18   Express          Wednesday      Plan  1.000000
# 19  Standard             Friday      Plan  2.000000
# 20  Standard             Monday      Plan  1.000000
# 21  Standard           Saturday      Plan  1.000000
# 22  Standard             Sunday      Plan  1.000000
# 23  Standard           Thursday      Plan  3.000000
# 24  Standard            Tuesday      Plan  2.000000
# 25  Standard          Wednesday      Plan  1.000000

# %%
weekday_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

graph_2["order date_weekday"] = pd.Categorical(graph_2["order date_weekday"],categories=weekday_order, ordered=True)
graph_2
# Out:
#    ship mode order date_weekday data type      days
# 0    Express             Friday    Actual  0.000000
# 1    Express             Monday    Actual  0.500000
# 2    Express           Saturday    Actual  0.500000
# 3    Express           Thursday    Actual  0.200000
# 4    Express            Tuesday    Actual  0.846154
# 5    Express          Wednesday    Actual  0.090909
# 6   Standard             Friday    Actual  1.812500
# 7   Standard             Monday    Actual  2.280000
# 8   Standard           Saturday    Actual  2.777778
# 9   Standard             Sunday    Actual  1.666667
# 10  Standard           Thursday    Actual  1.857143
# 11  Standard            Tuesday    Actual  1.828571
# 12  Standard          Wednesday    Actual  2.000000
# 13   Express             Friday      Plan  0.000000
# 14   Express             Monday      Plan  1.000000
# 15   Express           Saturday      Plan  1.000000
# 16   Express           Thursday      Plan  0.000000
# 17   Express            Tuesday      Plan  0.000000
# 18   Express          Wednesday      Plan  1.000000
# 19  Standard             Friday      Plan  2.000000
# 20  Standard             Monday      Plan  1.000000
# 21  Standard           Saturday      Plan  1.000000
# 22  Standard             Sunday      Plan  1.000000
# 23  Standard           Thursday      Plan  3.000000
# 24  Standard            Tuesday      Plan  2.000000
# 25  Standard          Wednesday      Plan  1.000000

# %%
graph_2_express = graph_2[graph_2["ship mode"]=="Express"].sort_values("order date_weekday")
graph_2_standard = graph_2[graph_2["ship mode"]=="Standard"].sort_values("order date_weekday")

graph_2_express
# Out:
#    ship mode order date_weekday data type      days
# 1    Express             Monday    Actual  0.500000
# 14   Express             Monday      Plan  1.000000
# 4    Express            Tuesday    Actual  0.846154
# 17   Express            Tuesday      Plan  0.000000
# 5    Express          Wednesday    Actual  0.090909
# 18   Express          Wednesday      Plan  1.000000
# 3    Express           Thursday    Actual  0.200000
# 16   Express           Thursday      Plan  0.000000
# 0    Express             Friday    Actual  0.000000
# 13   Express             Friday      Plan  0.000000
# 2    Express           Saturday    Actual  0.500000
# 15   Express           Saturday      Plan  1.000000

# %% [markdown]
# #### Plots

# %%
graph = graph_1
bar_width = 0.7
offset = (bar_width / 4) # This calculates the offset needed to center on the 'Actual' bar

plt.figure(figsize=(10, 7))

ax = sns.barplot(data=graph, 
             x= "ship mode",
             y = "days",
             hue="data type",
             hue_order=["Actual","Plan"],
             width=bar_width
            )
ax.set_ylim(-0.1, 3.2)
plt.title('Order ready for shipment 2 leaving warehouse', fontsize=16,pad=20)
plt.xlabel("Shipping type")
plt.ylabel("Days")
plt.legend()


# Calculate and display the uplift (difference) as text above the bars
# Iterate through each ship mode ('Express' and 'Standard')
for i, ship_mode in enumerate(graph["ship mode"].unique()):
    # Get the 'Actual' and 'Plan' values for the current ship mode
    actual_days = graph[(graph["ship mode"] == ship_mode) & (graph["data type"] == "Actual")]["days"].iloc[0]
    plan_days = graph[(graph["ship mode"] == ship_mode) & (graph["data type"] == "Plan")]["days"].iloc[0]

    uplift = actual_days - plan_days
    
    # X-POSITION: Centered over the 'Actual' bar.
    # The first bar group (Express, i=0) is at x=0. The second (Standard, i=1) is at x=1.
    # The 'Actual' bar is typically slightly to the left of the center point (i - offset).
    x_pos = i - offset
    # y-position: slightly above the higher bar for the annotation
    y_pos = actual_days +0.05 # Adjust vertical position as needed

    # Determine text color (Green for improvement (lower days), Red for regression (higher days))
    color = "black"
    
    # Format the uplift text (e.g., "+0.50 days" or "-0.25 days")
    uplift_text = f"{uplift:+.1f} d." # Using + to explicitly show positive or negative

    # Add the uplift text
    ax.text(x_pos, y_pos, uplift_text,
            color=color, ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.xticks()
plt.xticks()
plt.tight_layout()
plt.show(),
# Out:
# (None,)

# %%
graph = graph_2_standard

bar_width = 0.7
offset = (bar_width / 4) # This calculates the offset needed to center on the 'Actual' bar


plt.figure(figsize=(10, 7))

ax = sns.barplot(data=graph, 
             x= "order date_weekday",
             y = "days",
             hue="data type",
             hue_order=["Actual","Plan"],
             width=bar_width,
             errorbar=None
            )
ax.set_ylim(-0.1, 3.2)
plt.title('*Standard* order ready for shipment 2 leaving warehouse', fontsize=16,pad=20)
plt.xlabel("Order weekday")
plt.ylabel("Days")
plt.legend()



# Calculate and display the uplift (difference) as text above the bars
# Iterate through each unique WEEKDAY in the data
for i, weekday in enumerate(graph["order date_weekday"].unique()):
    # Get the 'Actual' and 'Plan' values for the current WEEKDAY
    
    # Filter the graph DataFrame by the current weekday
    weekday_data = graph[graph["order date_weekday"] == weekday]
    
    # Use the filtered data to extract the specific Actual and Plan values
    actual_days = weekday_data[weekday_data["data type"] == "Actual"]["days"].iloc[0]
    plan_days = weekday_data[weekday_data["data type"] == "Plan"]["days"].iloc[0]

    uplift = actual_days - plan_days
    
    # X-POSITION: Centered over the 'Actual' bar.
    # The first bar group (Express, i=0) is at x=0. The second (Standard, i=1) is at x=1.
    # The 'Actual' bar is typically slightly to the left of the center point (i - offset).
    x_pos = i - offset
    # y-position: slightly above the higher bar for the annotation
    y_pos = actual_days +0.05 # Adjust vertical position as needed

    # Determine text color (Green for improvement (lower days), Red for regression (higher days))
    color = "black"
    
    # Format the uplift text (e.g., "+0.50 days" or "-0.25 days")
    uplift_text = f"{uplift:+.1f} d." # Using + to explicitly show positive or negative

    # Add the uplift text
    ax.text(x_pos, y_pos, uplift_text,
            color=color, ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.xticks()
plt.xticks()
plt.tight_layout()
plt.show(),
# Out:
# (None,)

# %%
graph = graph_2_express

bar_width = 0.7
offset = (bar_width / 4) # This calculates the offset needed to center on the 'Actual' bar


plt.figure(figsize=(10, 7))

ax = sns.barplot(data=graph, 
             x= "order date_weekday",
             y = "days",
             hue="data type",
             hue_order=["Actual","Plan"],
             width=bar_width,
             errorbar=None
            )
ax.set_ylim(-0.1, 3.2)
plt.title('*Express* order ready for shipment 2 leaving warehouse', fontsize=16,pad=20)
plt.xlabel("Order weekday")
plt.ylabel("Days")
plt.legend()


# Calculate and display the uplift (difference) as text above the bars
# Iterate through each unique WEEKDAY in the data
for i, weekday in enumerate(graph["order date_weekday"].unique()):
    # Get the 'Actual' and 'Plan' values for the current WEEKDAY
    
    # Filter the graph DataFrame by the current weekday
    weekday_data = graph[graph["order date_weekday"] == weekday]
    
    # Use the filtered data to extract the specific Actual and Plan values
    actual_days = weekday_data[weekday_data["data type"] == "Actual"]["days"].iloc[0]
    plan_days = weekday_data[weekday_data["data type"] == "Plan"]["days"].iloc[0]

    uplift = actual_days - plan_days
    
    # X-POSITION: Centered over the 'Actual' bar.
    # The first bar group (Express, i=0) is at x=0. The second (Standard, i=1) is at x=1.
    # The 'Actual' bar is typically slightly to the left of the center point (i - offset).
    x_pos = i - offset
    # y-position: slightly above the higher bar for the annotation
    y_pos = actual_days +0.05 # Adjust vertical position as needed

    # Determine text color (Green for improvement (lower days), Red for regression (higher days))
    color = "black"
    
    # Format the uplift text (e.g., "+0.50 days" or "-0.25 days")
    uplift_text = f"{uplift:+.1f} d." # Using + to explicitly show positive or negative

    # Add the uplift text
    ax.text(x_pos, y_pos, uplift_text,
            color=color, ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.xticks()
plt.xticks()
plt.tight_layout()
plt.show(),
# Out:
# (None,)

# %%
graph_2_express
# Out:
#    ship mode order date_weekday data type      days
# 1    Express             Monday    Actual  0.500000
# 14   Express             Monday      Plan  1.000000
# 4    Express            Tuesday    Actual  0.846154
# 17   Express            Tuesday      Plan  0.000000
# 5    Express          Wednesday    Actual  0.090909
# 18   Express          Wednesday      Plan  1.000000
# 3    Express           Thursday    Actual  0.200000
# 16   Express           Thursday      Plan  0.000000
# 0    Express             Friday    Actual  0.000000
# 13   Express             Friday      Plan  0.000000
# 2    Express           Saturday    Actual  0.500000
# 15   Express           Saturday      Plan  1.000000

# %% [markdown]
# ### o_truck_2_delivered

# %% [markdown]
# #### Merging data

# %%
merged_o_truck_2_delivered=pd.merge(df_campaign_cleaned,df_order_process_cleaned, on='order id', how='inner' )

# %%
merged_o_truck_2_delivered
# Out:
#            order id arrival scan date on truck scan date
# 0    CA-2019-109666        2019-05-03         2019-04-29
# 1    CA-2019-138933        2019-05-03         2019-04-29
# 2    CA-2019-130001        2019-05-03         2019-05-01
# 3    CA-2019-113061        2019-05-06         2019-04-29
# 4    CA-2019-162138        2019-05-06         2019-05-01
# ..              ...               ...                ...
# 328  CA-2020-129707        2020-05-08         2020-05-04
# 329  CA-2020-125381        2020-05-08         2020-05-01
# 330  CA-2020-141733        2020-05-15         2020-05-13
# 331  US-2020-104451        2020-05-15         2020-05-13
# 332  US-2020-139647        2020-05-15         2020-05-13
#
# [333 rows x 3 columns]

# %%
merged_o_truck_2_delivered = pd.merge(
    merged_o_truck_2_delivered,
    df_orders_cleaned[['order id', 'ship mode']],  # include key + column you want
    on='order id',
    how='inner'
)

# %%
merged_o_truck_2_delivered
# Out:
#            order id arrival scan date on truck scan date ship mode
# 0    CA-2019-109666        2019-05-03         2019-04-29  Standard
# 1    CA-2019-138933        2019-05-03         2019-04-29   Express
# 2    CA-2019-130001        2019-05-03         2019-05-01  Standard
# 3    CA-2019-113061        2019-05-06         2019-04-29  Standard
# 4    CA-2019-162138        2019-05-06         2019-05-01  Standard
# ..              ...               ...                ...       ...
# 328  CA-2020-129707        2020-05-08         2020-05-04  Standard
# 329  CA-2020-125381        2020-05-08         2020-05-01  Standard
# 330  CA-2020-141733        2020-05-15         2020-05-13  Standard
# 331  US-2020-104451        2020-05-15         2020-05-13  Standard
# 332  US-2020-139647        2020-05-15         2020-05-13   Express
#
# [333 rows x 4 columns]

# %% [markdown]
# #### checking na data

# %%
merged_o_truck_2_delivered.isna().sum()
# Out:
# order id              0
# arrival scan date     0
# on truck scan date    0
# ship mode             0
# dtype: int64

# %% [markdown]
# #### calculating time interval between on truck scan date and arrival scan date

# %%
merged_o_truck_2_delivered['time interval']=merged_o_truck_2_delivered['arrival scan date']-merged_o_truck_2_delivered['on truck scan date']

# %%
merged_o_truck_2_delivered
# Out:
#            order id arrival scan date on truck scan date ship mode  \
# 0    CA-2019-109666        2019-05-03         2019-04-29  Standard
# 1    CA-2019-138933        2019-05-03         2019-04-29   Express
# 2    CA-2019-130001        2019-05-03         2019-05-01  Standard
# 3    CA-2019-113061        2019-05-06         2019-04-29  Standard
# 4    CA-2019-162138        2019-05-06         2019-05-01  Standard
# ..              ...               ...                ...       ...
# 328  CA-2020-129707        2020-05-08         2020-05-04  Standard
# 329  CA-2020-125381        2020-05-08         2020-05-01  Standard
# 330  CA-2020-141733        2020-05-15         2020-05-13  Standard
# 331  US-2020-104451        2020-05-15         2020-05-13  Standard
# 332  US-2020-139647        2020-05-15         2020-05-13   Express
#
#     time interval
# 0          4 days
# 1          4 days
# 2          2 days
# 3          7 days
# 4          5 days
# ..            ...
# 328        4 days
# 329        7 days
# 330        2 days
# 331        2 days
# 332        2 days
#
# [333 rows x 5 columns]

# %% [markdown]
# #### extracting the days for arrival date

# %%
merged_o_truck_2_delivered["arrival year"]= merged_o_truck_2_delivered["arrival scan date"].dt.year
merged_o_truck_2_delivered["arrival month"]= merged_o_truck_2_delivered["arrival scan date"].dt.month
merged_o_truck_2_delivered["arrival day"]= merged_o_truck_2_delivered["arrival scan date"].dt.dayofweek

# %%
merged_o_truck_2_delivered
# Out:
#            order id arrival scan date on truck scan date ship mode  \
# 0    CA-2019-109666        2019-05-03         2019-04-29  Standard
# 1    CA-2019-138933        2019-05-03         2019-04-29   Express
# 2    CA-2019-130001        2019-05-03         2019-05-01  Standard
# 3    CA-2019-113061        2019-05-06         2019-04-29  Standard
# 4    CA-2019-162138        2019-05-06         2019-05-01  Standard
# ..              ...               ...                ...       ...
# 328  CA-2020-129707        2020-05-08         2020-05-04  Standard
# 329  CA-2020-125381        2020-05-08         2020-05-01  Standard
# 330  CA-2020-141733        2020-05-15         2020-05-13  Standard
# 331  US-2020-104451        2020-05-15         2020-05-13  Standard
# 332  US-2020-139647        2020-05-15         2020-05-13   Express
#
#     time interval  arrival year  arrival month  arrival day
# 0          4 days          2019              5            4
# 1          4 days          2019              5            4
# 2          2 days          2019              5            4
# 3          7 days          2019              5            0
# 4          5 days          2019              5            0
# ..            ...           ...            ...          ...
# 328        4 days          2020              5            4
# 329        7 days          2020              5            4
# 330        2 days          2020              5            4
# 331        2 days          2020              5            4
# 332        2 days          2020              5            4
#
# [333 rows x 8 columns]

# %%
merged_o_truck_2_delivered['arrival day'].value_counts()
# Out:
# arrival day
# 0    215
# 1     40
# 4     39
# 2     20
# 3     19
# Name: count, dtype: int64

# %% [markdown]
# #### transforming arrival day into weekdays and weekend dates

# %%
arrival_day_categories={0: 'monday', 1: 'tuesday', 2: 'wednesday', 3: 'thursday', 4:'friday', 5:'friday', 6:'saturday', 7:'sunday'}
merged_o_truck_2_delivered['arrival day']=merged_o_truck_2_delivered['arrival day'].map(arrival_day_categories)
merged_o_truck_2_delivered
# Out:
#            order id arrival scan date on truck scan date ship mode  \
# 0    CA-2019-109666        2019-05-03         2019-04-29  Standard
# 1    CA-2019-138933        2019-05-03         2019-04-29   Express
# 2    CA-2019-130001        2019-05-03         2019-05-01  Standard
# 3    CA-2019-113061        2019-05-06         2019-04-29  Standard
# 4    CA-2019-162138        2019-05-06         2019-05-01  Standard
# ..              ...               ...                ...       ...
# 328  CA-2020-129707        2020-05-08         2020-05-04  Standard
# 329  CA-2020-125381        2020-05-08         2020-05-01  Standard
# 330  CA-2020-141733        2020-05-15         2020-05-13  Standard
# 331  US-2020-104451        2020-05-15         2020-05-13  Standard
# 332  US-2020-139647        2020-05-15         2020-05-13   Express
#
#     time interval  arrival year  arrival month arrival day
# 0          4 days          2019              5      friday
# 1          4 days          2019              5      friday
# 2          2 days          2019              5      friday
# 3          7 days          2019              5      monday
# 4          5 days          2019              5      monday
# ..            ...           ...            ...         ...
# 328        4 days          2020              5      friday
# 329        7 days          2020              5      friday
# 330        2 days          2020              5      friday
# 331        2 days          2020              5      friday
# 332        2 days          2020              5      friday
#
# [333 rows x 8 columns]

# %% [markdown]
# #### extracting the days for on truck scan date

# %%
merged_o_truck_2_delivered["on truck year"]= merged_o_truck_2_delivered["on truck scan date"].dt.year
merged_o_truck_2_delivered["on truck month"]= merged_o_truck_2_delivered["on truck scan date"].dt.month
merged_o_truck_2_delivered["on truck day"]= merged_o_truck_2_delivered["on truck scan date"].dt.dayofweek

# %%
merged_o_truck_2_delivered
# Out:
#            order id arrival scan date on truck scan date ship mode  \
# 0    CA-2019-109666        2019-05-03         2019-04-29  Standard
# 1    CA-2019-138933        2019-05-03         2019-04-29   Express
# 2    CA-2019-130001        2019-05-03         2019-05-01  Standard
# 3    CA-2019-113061        2019-05-06         2019-04-29  Standard
# 4    CA-2019-162138        2019-05-06         2019-05-01  Standard
# ..              ...               ...                ...       ...
# 328  CA-2020-129707        2020-05-08         2020-05-04  Standard
# 329  CA-2020-125381        2020-05-08         2020-05-01  Standard
# 330  CA-2020-141733        2020-05-15         2020-05-13  Standard
# 331  US-2020-104451        2020-05-15         2020-05-13  Standard
# 332  US-2020-139647        2020-05-15         2020-05-13   Express
#
#     time interval  arrival year  arrival month arrival day  on truck year  \
# 0          4 days          2019              5      friday           2019
# 1          4 days          2019              5      friday           2019
# 2          2 days          2019              5      friday           2019
# 3          7 days          2019              5      monday           2019
# 4          5 days          2019              5      monday           2019
# ..            ...           ...            ...         ...            ...
# 328        4 days          2020              5      friday           2020
# 329        7 days          2020              5      friday           2020
# 330        2 days          2020              5      friday           2020
# 331        2 days          2020              5      friday           2020
# 332        2 days          2020              5      friday           2020
#
#      on truck month  on truck day
# 0                 4             0
# 1                 4             0
# 2                 5             2
# 3                 4             0
# 4                 5             2
# ..              ...           ...
# 328               5             0
# 329               5             4
# 330               5             2
# 331               5             2
# 332               5             2
#
# [333 rows x 11 columns]

# %%
merged_o_truck_2_delivered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order id            333 non-null    object
#  1   arrival scan date   333 non-null    datetime64[ns]
#  2   on truck scan date  333 non-null    datetime64[ns]
#  3   ship mode           333 non-null    object
#  4   time interval       333 non-null    timedelta64[ns]
#  5   arrival year        333 non-null    int32
#  6   arrival month       333 non-null    int32
#  7   arrival day         333 non-null    object
#  8   on truck year       333 non-null    int32
#  9   on truck month      333 non-null    int32
#  10  on truck day        333 non-null    int32
# dtypes: datetime64[ns](2), int32(5), object(3), timedelta64[ns](1)
# memory usage: 22.2+ KB

# %%
merged_o_truck_2_delivered['actual duration']=merged_o_truck_2_delivered['time interval'].dt.days

# %%
merged_o_truck_2_delivered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order id            333 non-null    object
#  1   arrival scan date   333 non-null    datetime64[ns]
#  2   on truck scan date  333 non-null    datetime64[ns]
#  3   ship mode           333 non-null    object
#  4   time interval       333 non-null    timedelta64[ns]
#  5   arrival year        333 non-null    int32
#  6   arrival month       333 non-null    int32
#  7   arrival day         333 non-null    object
#  8   on truck year       333 non-null    int32
#  9   on truck month      333 non-null    int32
#  10  on truck day        333 non-null    int32
#  11  actual duration     333 non-null    int64
# dtypes: datetime64[ns](2), int32(5), int64(1), object(3), timedelta64[ns](1)
# memory usage: 24.8+ KB

# %%
merged_o_truck_2_delivered['on truck day'].value_counts()
# Out:
# on truck day
# 2    199
# 4     78
# 0     46
# 1     10
# Name: count, dtype: int64

# %% [markdown]
# #### transforming on truck scan date into weekdays and weekends date

# %%
on_truck_day_categories={0: 'monday', 1: 'tuesday', 2: 'wednesday', 3: 'thursday', 4:'friday', 5:'friday', 6:'saturday', 7:'sunday'}
merged_o_truck_2_delivered['on truck day']=merged_o_truck_2_delivered['on truck day'].map(on_truck_day_categories)
merged_o_truck_2_delivered
# Out:
#            order id arrival scan date on truck scan date ship mode  \
# 0    CA-2019-109666        2019-05-03         2019-04-29  Standard
# 1    CA-2019-138933        2019-05-03         2019-04-29   Express
# 2    CA-2019-130001        2019-05-03         2019-05-01  Standard
# 3    CA-2019-113061        2019-05-06         2019-04-29  Standard
# 4    CA-2019-162138        2019-05-06         2019-05-01  Standard
# ..              ...               ...                ...       ...
# 328  CA-2020-129707        2020-05-08         2020-05-04  Standard
# 329  CA-2020-125381        2020-05-08         2020-05-01  Standard
# 330  CA-2020-141733        2020-05-15         2020-05-13  Standard
# 331  US-2020-104451        2020-05-15         2020-05-13  Standard
# 332  US-2020-139647        2020-05-15         2020-05-13   Express
#
#     time interval  arrival year  arrival month arrival day  on truck year  \
# 0          4 days          2019              5      friday           2019
# 1          4 days          2019              5      friday           2019
# 2          2 days          2019              5      friday           2019
# 3          7 days          2019              5      monday           2019
# 4          5 days          2019              5      monday           2019
# ..            ...           ...            ...         ...            ...
# 328        4 days          2020              5      friday           2020
# 329        7 days          2020              5      friday           2020
# 330        2 days          2020              5      friday           2020
# 331        2 days          2020              5      friday           2020
# 332        2 days          2020              5      friday           2020
#
#      on truck month on truck day  actual duration
# 0                 4       monday                4
# 1                 4       monday                4
# 2                 5    wednesday                2
# 3                 4       monday                7
# 4                 5    wednesday                5
# ..              ...          ...              ...
# 328               5       monday                4
# 329               5       friday                7
# 330               5    wednesday                2
# 331               5    wednesday                2
# 332               5    wednesday                2
#
# [333 rows x 12 columns]

# %%
merged_o_truck_2_delivered['on truck day'].value_counts()
# Out:
# on truck day
# wednesday    199
# friday        78
# monday        46
# tuesday       10
# Name: count, dtype: int64

# %%
merged_o_truck_2_delivered['arrival day'].value_counts()
# Out:
# arrival day
# monday       215
# tuesday       40
# friday        39
# wednesday     20
# thursday      19
# Name: count, dtype: int64

# %% [markdown]
# #### calculating the average actual duration of on truck to delivery

# %%
result_on_truck=merged_o_truck_2_delivered.groupby(['ship mode','on truck day'])['actual duration'].mean().round(2).reset_index()

# %%
result_on_truck
# Out:
#   ship mode on truck day  actual duration
# 0   Express       friday             3.79
# 1   Express       monday             4.88
# 2   Express      tuesday             5.33
# 3   Express    wednesday             4.86
# 4  Standard       friday             4.12
# 5  Standard       monday             4.33
# 6  Standard      tuesday             5.00
# 7  Standard    wednesday             4.83

# %%
result_on_truck["expected duration"] = [3, 3, 2, 4, 3, 3, 4, 4]

# %%
result_on_truck
# Out:
#   ship mode on truck day  actual duration  expected duration
# 0   Express       friday             3.79                  3
# 1   Express       monday             4.88                  3
# 2   Express      tuesday             5.33                  2
# 3   Express    wednesday             4.86                  4
# 4  Standard       friday             4.12                  3
# 5  Standard       monday             4.33                  3
# 6  Standard      tuesday             5.00                  4
# 7  Standard    wednesday             4.83                  4

# %%
result_arrival=merged_o_truck_2_delivered.groupby(['ship mode','arrival day'])['actual duration'].mean().round(2).reset_index()

# %%
result_arrival
# Out:
#   ship mode arrival day  actual duration
# 0   Express      friday             3.30
# 1   Express      monday             4.64
# 2   Express    thursday             3.60
# 3   Express     tuesday             4.82
# 4   Express   wednesday             5.29
# 5  Standard      friday             3.34
# 6  Standard      monday             4.90
# 7  Standard    thursday             3.79
# 8  Standard     tuesday             4.86
# 9  Standard   wednesday             4.54

# %%
result_arrival["expected duration"] = [3, 3, 2, 4, 4, 3, 3, 4, 4, 3]

# %%
result_arrival
# Out:
#   ship mode arrival day  actual duration  expected duration
# 0   Express      friday             3.30                  3
# 1   Express      monday             4.64                  3
# 2   Express    thursday             3.60                  2
# 3   Express     tuesday             4.82                  4
# 4   Express   wednesday             5.29                  4
# 5  Standard      friday             3.34                  3
# 6  Standard      monday             4.90                  3
# 7  Standard    thursday             3.79                  4
# 8  Standard     tuesday             4.86                  4
# 9  Standard   wednesday             4.54                  3

# %%
result_on_truck.query("`ship mode` == 'Standard'")
# Out:
#   ship mode on truck day  actual duration  expected duration
# 4  Standard       friday             4.12                  3
# 5  Standard       monday             4.33                  3
# 6  Standard      tuesday             5.00                  4
# 7  Standard    wednesday             4.83                  4

# %%
merged_o_truck_2_delivered_weekdays_on_truck = merged_o_truck_2_delivered.query(
    "`on truck day` in ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']"
)

# %%
merged_o_truck_2_delivered_weekdays_on_truck = merged_o_truck_2_delivered.query(
    "`on truck day` in ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']"
)

# %%
average_actual_duration_weekdays_on_truck= merged_o_truck_2_delivered_weekdays_on_truck.groupby('ship mode')['actual duration'].mean().round(2)

# %%
average_actual_duration_weekdays_on_truck= merged_o_truck_2_delivered_weekdays_on_truck.groupby('ship mode')['actual duration'].mean().round(2)

# %%
merged_o_truck_2_delivered_weekdays_arrival = merged_o_truck_2_delivered.query(
    "`arrival day` in ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']"
)

# %%
merged_o_truck_2_delivered_weekdays_arrival
# Out:
#            order id arrival scan date on truck scan date ship mode  \
# 0    CA-2019-109666        2019-05-03         2019-04-29  Standard
# 1    CA-2019-138933        2019-05-03         2019-04-29   Express
# 2    CA-2019-130001        2019-05-03         2019-05-01  Standard
# 3    CA-2019-113061        2019-05-06         2019-04-29  Standard
# 4    CA-2019-162138        2019-05-06         2019-05-01  Standard
# ..              ...               ...                ...       ...
# 328  CA-2020-129707        2020-05-08         2020-05-04  Standard
# 329  CA-2020-125381        2020-05-08         2020-05-01  Standard
# 330  CA-2020-141733        2020-05-15         2020-05-13  Standard
# 331  US-2020-104451        2020-05-15         2020-05-13  Standard
# 332  US-2020-139647        2020-05-15         2020-05-13   Express
#
#     time interval  arrival year  arrival month arrival day  on truck year  \
# 0          4 days          2019              5      friday           2019
# 1          4 days          2019              5      friday           2019
# 2          2 days          2019              5      friday           2019
# 3          7 days          2019              5      monday           2019
# 4          5 days          2019              5      monday           2019
# ..            ...           ...            ...         ...            ...
# 328        4 days          2020              5      friday           2020
# 329        7 days          2020              5      friday           2020
# 330        2 days          2020              5      friday           2020
# 331        2 days          2020              5      friday           2020
# 332        2 days          2020              5      friday           2020
#
#      on truck month on truck day  actual duration
# 0                 4       monday                4
# 1                 4       monday                4
# 2                 5    wednesday                2
# 3                 4       monday                7
# 4                 5    wednesday                5
# ..              ...          ...              ...
# 328               5       monday                4
# 329               5       friday                7
# 330               5    wednesday                2
# 331               5    wednesday                2
# 332               5    wednesday                2
#
# [333 rows x 12 columns]

# %%
merged_o_truck_2_delivered_weekends_arrival= merged_o_truck_2_delivered.query(
    "`arrival day` in ['saturday', 'sunday']")

# %%
merged_o_truck_2_delivered_weekends_arrival
# Out:
# Empty DataFrame
# Columns: [order id, arrival scan date, on truck scan date, ship mode, time interval, arrival year, arrival month, arrival day, on truck year, on truck month, on truck day, actual duration]
# Index: []

# %% [markdown]
# #### visualization

# %%
# Data including missing days
standard_data = pd.DataFrame({
    "on_truck_day": ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"],
    "actual duration": [4.33, 5.00, 4.83, None, 4.12, None, None],  # actual durations
    "expected duration normal": [3, 4, 4, 3, 3, 3, 3]  # expected durations
})

day_order = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]

plt.figure(figsize=(12,6))
sns.set_style("whitegrid")
sns.set_context("talk")

# Barplot for actual duration
bars = sns.barplot(
    x="on_truck_day",
    y="actual duration",
    data=standard_data,
    palette="Blues_d",
    order=day_order,
    alpha=0.8
)

# Overlay expected duration as dashed line with points
plt.plot(
    day_order,
    standard_data["expected duration normal"],
    color="#FF6F61",  # soft red
    marker="o",
    linestyle="--",
    linewidth=2,
    markersize=8,
    label="Expected Duration"
)

# Annotate bars with actual duration
for i, val in enumerate(standard_data["actual duration"]):
    if val is not None:
        bars.text(i, val + 0.1, f"{val:.1f}", ha='center', va='bottom', fontsize=12, color='navy')

# Annotate expected durations on points
for i, val in enumerate(standard_data["expected duration normal"]):
    plt.text(i, val + 0.1, f"{val:.1f}", ha='center', va='bottom', fontsize=12, color='#FF6F61')

# Labels and title
plt.ylabel("Duration (days)", fontsize=14)
plt.xlabel("On Truck Day", fontsize=14)
plt.title("Actual vs Expected Duration for Standard Ship Mode", fontsize=16, weight='bold')
plt.legend(frameon=True, facecolor='white', edgecolor='black')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(0, max(standard_data["actual duration"].max(), max(standard_data["expected duration normal"])) + 2)

# Save figure
plt.savefig('Actual vs Expected Duration for Standard Ship Mode for On Truck', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/sc/3s_b29hx6kz96y_6tzpvlnfm0000gn/T/ipykernel_12254/3869407665.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(

# %%
result_arrival.query("`ship mode` == 'Standard'")
# Out:
#   ship mode arrival day  actual duration  expected duration
# 5  Standard      friday             3.34                  3
# 6  Standard      monday             4.90                  3
# 7  Standard    thursday             3.79                  4
# 8  Standard     tuesday             4.86                  4
# 9  Standard   wednesday             4.54                  3

# %%
# Data including missing days
standard_data = pd.DataFrame({
    "arrival_day": ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"],
    "actual duration": [4.90, 4.86, 4.54, 3.79, 3.34, None, None],  # actual durations
    "expected duration normal": [3, 4, 4, 3, 3, 3, 3]  # expected durations
})

day_order = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]

plt.figure(figsize=(12,6))
sns.set_style("whitegrid")
sns.set_context("talk")

# Barplot for actual duration
bars = sns.barplot(
    x="arrival_day",
    y="actual duration",
    data=standard_data,
    palette="Blues_d",
    order=day_order,
    alpha=0.8
)

# Overlay expected duration as dashed line with points
plt.plot(
    day_order,
    standard_data["expected duration normal"],
    color="#FF6F61",  # soft red
    marker="o",
    linestyle="--",
    linewidth=2,
    markersize=8,
    label="Expected Duration"
)

# Annotate bars with actual duration
for i, val in enumerate(standard_data["actual duration"]):
    if val is not None:
        bars.text(i, val + 0.1, f"{val:.1f}", ha='center', va='bottom', fontsize=12, color='navy')

# Annotate expected durations on points
for i, val in enumerate(standard_data["expected duration normal"]):
    plt.text(i, val + 0.1, f"{val:.1f}", ha='center', va='bottom', fontsize=12, color='#FF6F61')

# Labels and title
plt.ylabel("Duration (days)", fontsize=14)
plt.xlabel("Arrival Day", fontsize=14)
plt.title("Actual vs Expected Duration for Standard Ship Mode", fontsize=16, weight='bold')
plt.legend(frameon=True, facecolor='white', edgecolor='black')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(0, max(standard_data["actual duration"].max(), max(standard_data["expected duration normal"])) + 2)

# Save figure
plt.savefig('Actual vs Expected Duration for Standard Ship Mode for Arrival Day', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/sc/3s_b29hx6kz96y_6tzpvlnfm0000gn/T/ipykernel_12254/1207232642.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(

# %%
result_on_truck.query("`ship mode` == 'Express'")
# Out:
#   ship mode on truck day  actual duration  expected duration
# 0   Express       friday             3.79                  3
# 1   Express       monday             4.88                  3
# 2   Express      tuesday             5.33                  2
# 3   Express    wednesday             4.86                  4

# %%
# Data including all days
data = pd.DataFrame({
    "ship_mode": ["Express"]*7,
    "on_truck_day": ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"],
    "actual duration": [4.88, 5.33, 4.86, None, 3.79, None, None],  # actual durations
    "expected_duration": [3, 2, 4, 4, 3, 3, 3]  # expected durations
})

# Define the full day order
day_order = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]

plt.figure(figsize=(12,6))
sns.set_style("whitegrid")
sns.set_context("talk")

# Barplot for actual duration
bars = sns.barplot(
    x="on_truck_day",
    y="actual duration",
    data=data,
    palette="Oranges",
    order=day_order,
    alpha=0.8
)

# Overlay expected duration as line with points
plt.plot(
    day_order,
    data["expected_duration"],
    color="#FF6F61",  # red for expected
    marker="o",
    linestyle="--",
    linewidth=2,
    markersize=8,
    label="Expected Duration"
)

# Annotate actual durations
for i, val in enumerate(data["actual duration"]):
    if val is not None:
        bars.text(i, val + 0.1, f"{val:.1f}", ha='center', va='bottom', fontsize=12, color='brown')

# Annotate expected durations
for i, val in enumerate(data["expected_duration"]):
    bars.text(i, val + 0.1, f"{val:.1f}", ha='center', va='bottom', fontsize=12, color='#FF6F61')

plt.ylabel("Duration (days)", fontsize=14)
plt.xlabel("On Truck Day", fontsize=14)
plt.title("Actual vs Expected Duration for Express Ship Mode (All Days)", fontsize=16, weight='bold')
plt.legend()
plt.ylim(0, max(data["actual duration"].max(skipna=True), max(data["expected_duration"])) + 2)

# Save figure
plt.savefig('Actual vs Expected Duration for Express Ship Mode for On Truck', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/sc/3s_b29hx6kz96y_6tzpvlnfm0000gn/T/ipykernel_12254/489017136.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(

# %%
result_arrival.query("`ship mode` == 'Express'")
# Out:
#   ship mode arrival day  actual duration  expected duration
# 0   Express      friday             3.30                  3
# 1   Express      monday             4.64                  3
# 2   Express    thursday             3.60                  2
# 3   Express     tuesday             4.82                  4
# 4   Express   wednesday             5.29                  4

# %%
# Data including all days
data = pd.DataFrame({
    "ship_mode": ["Express"]*7,
    "arrival_day": ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"],
    "actual duration": [4.64, 4.82, 5.29, 3.60, 3.30, None, None],  # actual durations
    "expected_duration": [3, 2, 4, 4, 3, 3, 3]  # expected durations
})

# Define the full day order
day_order = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]

plt.figure(figsize=(12,6))
sns.set_style("whitegrid")
sns.set_context("talk")

# Barplot for actual duration
bars = sns.barplot(
    x="arrival_day",
    y="actual duration",
    data=data,
    palette="Oranges",
    order=day_order,
    alpha=0.8
)

# Overlay expected duration as line with points
plt.plot(
    day_order,
    data["expected_duration"],
    color="#FF6F61",  # red for expected
    marker="o",
    linestyle="--",
    linewidth=2,
    markersize=8,
    label="Expected Duration"
)

# Annotate actual durations
for i, val in enumerate(data["actual duration"]):
    if val is not None:
        bars.text(i, val + 0.1, f"{val:.1f}", ha='center', va='bottom', fontsize=12, color='brown')

# Annotate expected durations
for i, val in enumerate(data["expected_duration"]):
    bars.text(i, val + 0.1, f"{val:.1f}", ha='center', va='bottom', fontsize=12, color='#FF6F61')

plt.ylabel("Duration (days)", fontsize=14)
plt.xlabel("Arrival Day", fontsize=14)
plt.title("Actual vs Expected Duration for Express Ship Mode (All Days)", fontsize=16, weight='bold')
plt.legend()
plt.ylim(0, max(data["actual duration"].max(skipna=True), max(data["expected_duration"])) + 2)

# Save figure
plt.savefig('Actual vs Expected Duration for Express Ship Mode for Arrival Day', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# /var/folders/sc/3s_b29hx6kz96y_6tzpvlnfm0000gn/T/ipykernel_12254/3757862092.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(

# %%
average_actual_duration_weekdays_on_truck
# Out:
# ship mode
# Express     4.48
# Standard    4.64
# Name: actual duration, dtype: float64

# %%
average_actual_duration_weekdays_on_truck
# Out:
# ship mode
# Express     4.48
# Standard    4.64
# Name: actual duration, dtype: float64

# %%
# Dataset
data = {
    'Day Type': ['Weekdays', 'Weekend'],
    'Express': [4.48, None],
    'Standard': [4.64, None]
}
df = pd.DataFrame(data)

# Melt for seaborn
df_melted = df.melt(
    id_vars='Day Type',
    value_vars=['Express', 'Standard'],
    var_name='Ship Mode',
    value_name='Average Duration'
)

# Color palette
palette = {'Express': '#1f77b4', 'Standard': '#ff7f0e'}

# Plot
sns.set_style("whitegrid")
plt.figure(figsize=(8,6))
ax = sns.barplot(
    x='Day Type',
    y='Average Duration',
    hue='Ship Mode',
    data=df_melted,
    palette=palette,
    dodge=True,
    width=0.5
)

# Horizontal line for expected duration
plt.axhline(3, color='red', linestyle='--', linewidth=2, label='Expected Duration (3 days)')

# Add labels above bars with stagger and increased horizontal shift for Standard
stagger_amount = 0.1  # vertical offset to separate labels
horizontal_shift = 0.12  # increased horizontal offset for Standard

for p, (_, row) in zip(ax.patches, df_melted.iterrows()):
    val = row['Average Duration']
    if pd.notna(val):
        x = p.get_x() + p.get_width() / 2.
        y = val + stagger_amount if row['Ship Mode'] == 'Standard' else val
        # Shift Standard further to the right
        if row['Ship Mode'] == 'Standard':
            x += horizontal_shift
        ax.annotate(f"{val:.2f}",
                    (x, y),
                    ha='center', va='bottom',
                    fontsize=12, fontweight='bold')

# Style tweaks
plt.ylabel("Average Delivery Duration (days)", fontsize=14)
plt.xlabel("Day Type", fontsize=14)
plt.title("Average Truck-to-Delivery Duration by Ship Mode", fontsize=16, fontweight='bold')
plt.ylim(0, max(df_melted['Average Duration'].dropna()) + 0.5)

# Legend outside
plt.legend(title='Ship Mode', loc='upper left', bbox_to_anchor=(1,1), fontsize=12, title_fontsize=13)
sns.despine(left=True, bottom=True)

plt.tight_layout()

plt.savefig('Actual_Truck-to-Delivery_Duration_by_Ship_Mode.png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### o_date_2_delivered

# %%
merged_metric_2 = df_orders_cleaned.merge(df_campaign_cleaned, on="order id", how="outer").dropna()
merged_metric_2
# Out:
#             order id order date ship mode customer id country/region  \
# 1699  CA-2019-100041 2019-11-20  Standard    BF-10975  United States
# 1700  CA-2019-100083 2019-11-24  Standard    CD-11980  United States
# 1703  CA-2019-100244 2019-09-20  Standard    GM-14695  United States
# 1706  CA-2019-100468 2019-11-24  Standard    AT-10435  United States
# 1707  CA-2019-100510 2019-05-12  Standard    HM-14860  United States
# ...              ...        ...       ...         ...            ...
# 4897  US-2020-139647 2020-05-11   Express    TS-21370  United States
# 4931  US-2020-148551 2020-01-12  Standard    DB-13120  United States
# 4965  US-2020-158512 2020-01-12  Standard    DA-13450  United States
# 4981  US-2020-163195 2020-02-17  Standard    LL-16840  United States
# 5003  US-2020-168690 2020-01-07  Standard    TS-21085  United States
#
#                city                 state  postal code   region  \
# 1699       Columbus               Indiana      47201.0  Central
# 1700        Medford                Oregon      97504.0     West
# 1703  San Francisco            California      94122.0     West
# 1706    Los Angeles            California      90045.0     West
# 1707  New York City              New York      10024.0     East
# ...             ...                   ...          ...      ...
# 4897        Phoenix               Arizona      85023.0     West
# 4931         Dallas                 Texas      75217.0  Central
# 4965     Washington  District of Columbia      20016.0     East
# 4981      Lafayette             Louisiana      70506.0    South
# 5003   Ormond Beach               Florida      32174.0    South
#
#      arrival scan date
# 1699        2019-12-02
# 1700        2019-12-09
# 1703        2019-09-30
# 1706        2019-12-09
# 1707        2019-05-28
# ...                ...
# 4897        2020-05-15
# 4931        2020-01-22
# 4965        2020-01-27
# 4981        2020-03-02
# 5003        2020-01-20
#
# [333 rows x 10 columns]

# %%
merged_metric_2["date_diff"] = merged_metric_2["arrival scan date"]-merged_metric_2["order date"]
merged_metric_2
# Out:
#             order id order date ship mode customer id country/region  \
# 1699  CA-2019-100041 2019-11-20  Standard    BF-10975  United States
# 1700  CA-2019-100083 2019-11-24  Standard    CD-11980  United States
# 1703  CA-2019-100244 2019-09-20  Standard    GM-14695  United States
# 1706  CA-2019-100468 2019-11-24  Standard    AT-10435  United States
# 1707  CA-2019-100510 2019-05-12  Standard    HM-14860  United States
# ...              ...        ...       ...         ...            ...
# 4897  US-2020-139647 2020-05-11   Express    TS-21370  United States
# 4931  US-2020-148551 2020-01-12  Standard    DB-13120  United States
# 4965  US-2020-158512 2020-01-12  Standard    DA-13450  United States
# 4981  US-2020-163195 2020-02-17  Standard    LL-16840  United States
# 5003  US-2020-168690 2020-01-07  Standard    TS-21085  United States
#
#                city                 state  postal code   region  \
# 1699       Columbus               Indiana      47201.0  Central
# 1700        Medford                Oregon      97504.0     West
# 1703  San Francisco            California      94122.0     West
# 1706    Los Angeles            California      90045.0     West
# 1707  New York City              New York      10024.0     East
# ...             ...                   ...          ...      ...
# 4897        Phoenix               Arizona      85023.0     West
# 4931         Dallas                 Texas      75217.0  Central
# 4965     Washington  District of Columbia      20016.0     East
# 4981      Lafayette             Louisiana      70506.0    South
# 5003   Ormond Beach               Florida      32174.0    South
#
#      arrival scan date date_diff
# 1699        2019-12-02   12 days
# 1700        2019-12-09   15 days
# 1703        2019-09-30   10 days
# 1706        2019-12-09   15 days
# 1707        2019-05-28   16 days
# ...                ...       ...
# 4897        2020-05-15    4 days
# 4931        2020-01-22   10 days
# 4965        2020-01-27   15 days
# 4981        2020-03-02   14 days
# 5003        2020-01-20   13 days
#
# [333 rows x 11 columns]

# %%
merged_metric_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 1699 to 5003
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order id           333 non-null    object
#  1   order date         333 non-null    datetime64[ns]
#  2   ship mode          333 non-null    object
#  3   customer id        333 non-null    object
#  4   country/region     333 non-null    object
#  5   city               333 non-null    object
#  6   state              333 non-null    object
#  7   postal code        333 non-null    float64
#  8   region             333 non-null    object
#  9   arrival scan date  333 non-null    datetime64[ns]
#  10  date_diff          333 non-null    timedelta64[ns]
# dtypes: datetime64[ns](2), float64(1), object(7), timedelta64[ns](1)
# memory usage: 31.2+ KB

# %%
merged_metric_2["date_diff_days"] = merged_metric_2["date_diff"].dt.days

# %%
# 1. Distribution of date_diff
plt.figure(figsize=(8,5))
plt.hist(merged_metric_2["date_diff_days"], edgecolor="black")
plt.title("Distribution of date difference")
plt.xlabel("Days between order and arrival scan date")
plt.ylabel("Frequency")
plt.show()

# %%
# Order weekday (0=Monday, 6=Sunday)
merged_metric_2["order_weekday"] = merged_metric_2["order date"].dt.day_name()

# Ready-to-ship weekday
merged_metric_2["arrival_weekday"] = merged_metric_2["arrival scan date"].dt.day_name()

# %%
orders_by_day = merged_metric_2["order_weekday"].value_counts()
arrival_by_day = merged_metric_2["arrival_weekday"].value_counts()
avg_delay_by_day = merged_metric_2.groupby("order_weekday")["date_diff_days"].mean()

# %%
# 1 Order date by weekdays

orders_by_day = merged_metric_2["order_weekday"].value_counts().reindex(
    ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
)

orders_by_day.plot(kind="bar", figsize=(8,5), color="skyblue", edgecolor="black")
plt.title("Orders by Weekday")
plt.ylabel("Number of Orders")
plt.show()

# %%
# 2 Arrival date by Weekdays

arrival_by_day= merged_metric_2["arrival_weekday"].value_counts().reindex(
    ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
)

arrival_by_day.plot(kind="bar", figsize=(8,5), color="lightgreen", edgecolor="black")
plt.title("Arrival by Weekday")
plt.ylabel("Number of Orders")
plt.show()

# %%
# 3 Average Arrival delay by Weekdays

avg_delay_by_day = merged_metric_2.groupby("order_weekday")["date_diff_days"].mean().reindex(
    ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
)

avg_delay_by_day.plot(kind="bar", figsize=(8,5), color="orange", edgecolor="black")
plt.title("Average Arrival Delay by Order Weekday")
plt.ylabel("Average Delay (days)")
plt.show()

# %%
# 

merged_metric_2["ship mode"] = merged_metric_2["ship mode"].str.replace(" Class","")
merged_metric_2["ship mode"] = merged_metric_2["ship mode"].str.replace("Second","Standard")
merged_metric_2["ship mode"] = merged_metric_2["ship mode"].str.replace("First","Express")

# %%
# 3 Average Arrival delay by Ship mode

avg_delay_by_day = merged_metric_2.groupby("ship mode")["date_diff_days"].mean()#.reindex(
#    ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
#)

avg_delay_by_day.plot(kind="bar", figsize=(8,5), color="orange", edgecolor="black")
plt.title("Average Arrival Delay by Order Weekday")
plt.ylabel("Average Delay (days)")
plt.show()

# %%
avg_delay = merged_metric_2.groupby(["order_weekday","ship mode"])["date_diff_days"].mean().round(2)
avg_delay
# Out:
# order_weekday  ship mode
# Friday         Express       7.83
#                Standard     10.71
# Monday         Express       6.56
#                Standard     13.03
# Saturday       Express       7.50
#                Standard     10.25
# Sunday         Express       7.59
#                Standard     12.49
# Thursday       Express       6.67
#                Standard     11.14
# Tuesday        Express       6.71
#                Standard     12.31
# Wednesday      Express       7.38
#                Standard     11.95
# Name: date_diff_days, dtype: float64

# %%
avg_diff_by_mode_2 = merged_metric_2.groupby("ship mode")["date_diff_days"].mean().reset_index().round(2)
avg_diff_by_mode_2
# Out:
#   ship mode  date_diff_days
# 0   Express            7.05
# 1  Standard           11.93

# %%
# 4 Average Arrival delay by Ship mode

avg_delay = merged_metric_2.groupby(["order_weekday","ship mode"])["date_diff_days"].mean().unstack()

# ensure weekday order
weekday_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
avg_delay = avg_delay.reindex(weekday_order)

# plot
avg_delay.plot(kind="bar", figsize=(12,6))
plt.title("Average Arrival Time by Weekday and Ship Mode")
plt.ylabel("Average Arrival Time (days)")
plt.xlabel("Order Weekday")
plt.xticks(rotation=45)
plt.legend(title="Ship Mode")
plt.show()

# %%
# actual average delay for Standard
actual_std = (
    merged_metric_2[merged_metric_2["ship mode"]=="Standard"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
)

# expected values
expected_data = {
    "order_weekday": ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],
    "expected_delay": [5,7,6,7,8,7,6]
}
expected_df = pd.DataFrame(expected_data).set_index("order_weekday")

# align both (reindex to weekday order)
weekday_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
actual_std = actual_std.reindex(weekday_order)
expected_df = expected_df.reindex(weekday_order)

# combine
comparison = pd.DataFrame({
    "Actual (Standard)": actual_std,
    "Expected (Standard)": expected_df["expected_delay"]
})

# plot
comparison.plot(kind="bar", figsize=(12,6))
plt.title("Standard Shipping Duration Time: Actual vs Expected")
plt.ylabel("Average Duration Time (days)")
plt.xlabel("Order Weekday")
plt.xticks(rotation=45)
plt.legend(title="Series")
plt.show()

# %%
# actual average delay for Express
actual_exp = (
    merged_metric_2[merged_metric_2["ship mode"]=="Express"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
)

# expected values
expected_data = {
    "order_weekday": ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],
    "expected_delay": [5,4,6,5,6,7,6]
}
expected_df = pd.DataFrame(expected_data).set_index("order_weekday")

# align both (reindex to weekday order)
weekday_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
actual_exp = actual_exp.reindex(weekday_order)
expected_df = expected_df.reindex(weekday_order)

# combine into comparison table
comparison = pd.DataFrame({
    "Actual (Express)": actual_exp,
    "Expected (Express)": expected_df["expected_delay"]
})

# plot
comparison.plot(kind="bar", figsize=(12,6))
plt.title("Express Shipping Duration Time: Actual vs Expected")
plt.ylabel("Average Time (days)")
plt.xlabel("Order Weekday")
plt.xticks(rotation=45)
plt.legend(title="Series")
plt.show()

# %%
# --- Express actual ---
actual_exp = (
    merged_metric_2[merged_metric_2["ship mode"]=="Express"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
)

# --- Express expected ---
expected_exp = {
    "order_weekday": ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],
    "Expected (Express)": [5,4,6,5,6,7,6]
}
expected_exp_df = pd.DataFrame(expected_exp).set_index("order_weekday")

# --- Standard actual ---
actual_std = (
    merged_metric_2[merged_metric_2["ship mode"]=="Standard"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
)

# --- Standard expected ---
expected_std = {
    "order_weekday": ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],
    "Expected (Standard)": [5,7,6,7,8,7,6]
}
expected_std_df = pd.DataFrame(expected_std).set_index("order_weekday")

# --- Reindex all to same weekday order ---
weekday_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
actual_exp = actual_exp.reindex(weekday_order)
actual_std = actual_std.reindex(weekday_order)
expected_exp_df = expected_exp_df.reindex(weekday_order)
expected_std_df = expected_std_df.reindex(weekday_order)

# --- Combine everything into one DataFrame ---
comparison = pd.DataFrame({
    "Actual (Express)": actual_exp,
    "Expected (Express)": expected_exp_df["Expected (Express)"],
    "Actual (Standard)": actual_std,
    "Expected (Standard)": expected_std_df["Expected (Standard)"]
})

# --- Plot ---
ax = comparison.plot(kind="bar", figsize=(16,10))
plt.title("Shipping Duration Time (Ordered - Arrival): Actual vs Expected (Express & Standard)")
plt.ylabel("Average Duration Time (days)")
plt.xlabel("Order Weekday")
plt.xticks(rotation=0)
plt.legend(title="Series")

# Add values on top of bars
for container in ax.containers:
    ax.bar_label(container, fmt="%.1f", label_type="edge", padding=2)

plt.show()

# %%
# weekday order
weekday_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
business_days = ["Monday","Tuesday","Wednesday","Thursday","Friday"]
weekend_days = ["Saturday","Sunday"]

# --- Express ---
# actual
actual_exp = (
    merged_metric_2[merged_metric_2["ship mode"]=="Express"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
    .reindex(weekday_order)
)

# expected
expected_exp_data = {
    "order_weekday": weekday_order,
    "expected_delay": [5,4,6,5,6,7,6]
}
expected_exp = pd.DataFrame(expected_exp_data).set_index("order_weekday").reindex(weekday_order)

# combine Express
comparison_exp = pd.DataFrame({
    "Actual (Express)": actual_exp,
    "Expected (Express)": expected_exp["expected_delay"]
})

# --- Standard ---
# actual
actual_std = (
    merged_metric_2[merged_metric_2["ship mode"]=="Standard"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
    .reindex(weekday_order)
)

# expected
expected_std_data = {
    "order_weekday": weekday_order,
    "expected_delay": [5,7,6,7,8,7,6]
}
expected_std = pd.DataFrame(expected_std_data).set_index("order_weekday").reindex(weekday_order)

# combine Standard
comparison_std = pd.DataFrame({
    "Actual (Standard)": actual_std,
    "Expected (Standard)": expected_std["expected_delay"]
})

# --- Split by business days & weekend ---
comparison_exp_business = comparison_exp.loc[business_days]
comparison_exp_weekend = comparison_exp.loc[weekend_days]

comparison_std_business = comparison_std.loc[business_days]
comparison_std_weekend = comparison_std.loc[weekend_days]

# --- Plot business days ---
fig, axes = plt.subplots(1, 2, figsize=(14,6), sharey=True)

comparison_exp_business.plot(kind="bar", ax=axes[0])
axes[0].set_title("Express - Business Days")
axes[0].set_ylabel("Average Duration Time (days)")
axes[0].set_xlabel("Order Weekday")
axes[0].set_xticklabels(comparison_exp_business.index, rotation=45)

comparison_std_business.plot(kind="bar", ax=axes[1])
axes[1].set_title("Standard - Business Days")
axes[1].set_xlabel("Order Weekday")
axes[1].set_xticklabels(comparison_std_business.index, rotation=45)

plt.suptitle("Shipping Duration: Business Days")
plt.tight_layout()
plt.show()

# --- Plot weekends ---
fig, axes = plt.subplots(1, 2, figsize=(10,6), sharey=True)

comparison_exp_weekend.plot(kind="bar", ax=axes[0])
axes[0].set_title("Express - Weekend")
axes[0].set_ylabel("Average Duration Time (days)")
axes[0].set_xlabel("Order Weekday")
axes[0].set_xticklabels(comparison_exp_weekend.index, rotation=0)

comparison_std_weekend.plot(kind="bar", ax=axes[1])
axes[1].set_title("Standard - Weekend")
axes[1].set_xlabel("Order Weekday")
axes[1].set_xticklabels(comparison_std_weekend.index, rotation=0)

plt.suptitle("Shipping Duration: Weekend")
plt.tight_layout()
plt.show()

# %%
# weekday order + categories
weekday_order = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
business_days = ["Monday","Tuesday","Wednesday","Thursday","Friday"]
weekend_days = ["Saturday","Sunday"]

# --- Express ---
actual_exp = (
    merged_metric_2[merged_metric_2["ship mode"]=="Express"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
    .reindex(weekday_order)
)

expected_exp = pd.Series([5,4,6,5,6,7,6], index=weekday_order, name="Expected (Express)")

# --- Standard ---
actual_std = (
    merged_metric_2[merged_metric_2["ship mode"]=="Standard"]
    .groupby("order_weekday")["date_diff_days"]
    .mean()
    .reindex(weekday_order)
)

expected_std = pd.Series([5,7,6,7,8,7,6], index=weekday_order, name="Expected (Standard)")

# --- Combine into one long-format DataFrame ---
df_long = pd.DataFrame({
    "Actual (Express)": actual_exp,
    "Expected (Express)": expected_exp,
    "Actual (Standard)": actual_std,
    "Expected (Standard)": expected_std
}).reset_index().melt(id_vars="index", var_name="Type", value_name="Delay")

df_long.rename(columns={"index": "OrderWeekday"}, inplace=True)

# Add business/weekend label
df_long["DayType"] = df_long["OrderWeekday"].apply(lambda x: "Business" if x in business_days else "Weekend")

# --- Seaborn plot ---
plt.figure(figsize=(14,6))
sns.barplot(
    data=df_long,
    x="OrderWeekday", y="Delay", hue="Type",
    order=weekday_order
)

plt.title("Shipping Duration: Actual vs Expected (Express & Standard)\nBusiness Days vs Weekend Highlight")
plt.ylabel("Average Duration Time (days)")
plt.xlabel("Order Weekday")

# Highlight weekends with background shading
for i, day in enumerate(weekday_order):
    if day in weekend_days:
        plt.axvspan(i-0.5, i+0.5, color="lightgrey", alpha=0.3)

plt.legend(title="Series")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# --- Seaborn plot ---
plt.figure(figsize=(14,6))
ax = sns.barplot(
    data=df_long,
    x="OrderWeekday", y="Delay", hue="Type",
    order=weekday_order
)

plt.title("Shipping Duration: Actual vs Expected (Express & Standard)\nBusiness Days vs Weekend Highlight")
plt.ylabel("Average Duration Time (days)")
plt.xlabel("Order Weekday")

# Highlight weekends with background shading
for i, day in enumerate(weekday_order):
    if day in weekend_days:
        plt.axvspan(i-0.5, i+0.5, color="lightgrey", alpha=0.3)

# --- Add value labels ---
for p in ax.patches:
    height = p.get_height()
    ax.annotate(
        f"{height:.1f}",                       # 1 decimal place
        (p.get_x() + p.get_width() / 2., height),
        ha='center', va='bottom',
        fontsize=9, color="black", xytext=(0, 3), textcoords='offset points'
    )

plt.legend(title="Series")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### o_processed_2_delivered

# %% [markdown]
# #### Data

# %%
df_processed_x_delivered = df_campaign_cleaned.merge(df_interndata_cleaned, on="order id",how="inner")
df_processed_x_delivered
# Out:
#           order id arrival scan date ready to ship date
# 0   CA-2019-129630        2019-09-09         2019-09-04
# 1   CA-2019-129847        2019-09-10         2019-09-04
# 2   CA-2019-106278        2019-09-10         2019-09-05
# 3   CA-2019-158099        2019-09-11         2019-09-05
# 4   CA-2019-123120        2019-09-16         2019-09-09
# 5   CA-2019-149783        2019-09-16         2019-09-09
# 6   CA-2019-102981        2019-09-16         2019-09-09
# 7   CA-2019-110023        2019-09-16         2019-09-11
# 8   CA-2019-133123        2019-09-16         2019-09-11
# 9   CA-2019-149223        2019-09-17         2019-09-11
# 10  CA-2019-121223        2019-09-19         2019-09-13
# 11  US-2019-118780        2019-09-23         2019-09-16
# 12  CA-2019-146206        2019-09-23         2019-09-16
# 13  CA-2019-145625        2019-09-23         2019-09-17
# 14  CA-2019-130225        2019-09-23         2019-09-17
# 15  CA-2019-102932        2019-09-30         2019-09-23
# 16  CA-2019-168557        2019-09-30         2019-09-23
# 17  CA-2019-100244        2019-09-30         2019-09-24
# 18  CA-2019-145611        2019-09-30         2019-09-24
# 19  CA-2019-166772        2019-09-30         2019-09-24
# 20  CA-2019-141551        2019-10-07         2019-09-30
# 21  CA-2019-163202        2019-10-07         2019-10-02

# %% [markdown]
# #### Plots

# %%
#not enough data

# %% [markdown]
# ### KPI: o_date_2_processed

# %%
merged_metric_1.reset_index()
# Out:
#      index        order id order date ship mode customer id country/region  \
# 0     1703  CA-2019-100244 2019-09-20  Standard    GM-14695  United States
# 1     1711  CA-2019-100944 2019-09-24  Standard    EH-13765  United States
# 2     1740  CA-2019-102162 2019-09-11  Standard    JF-15565  United States
# 3     1747  CA-2019-102932 2019-09-19  Standard    SD-20485  United States
# 4     1748  CA-2019-102981 2019-09-06  Standard    MO-17500  United States
# ..     ...             ...        ...       ...         ...            ...
# 199   4984  US-2020-163790 2020-11-02  Standard    NL-18310  United States
# 200   4987  US-2020-165344 2020-11-13   Express    SB-20290  United States
# 201   4989  US-2020-165456 2020-11-30   Express    TB-21625  United States
# 202   5001  US-2020-168116 2020-11-04   Express    GT-14635  United States
# 203   5004  US-2020-168802 2020-11-03  Standard    JO-15145  United States
#
#               city           state  postal code region ready to ship date  \
# 0    San Francisco      California      94122.0   West         2019-09-24
# 1      Los Angeles      California      90049.0   West         2019-09-30
# 2     Newport News        Virginia      23602.0  South         2019-09-16
# 3           Orange      New Jersey       7050.0   East         2019-09-23
# 4    New York City        New York      10035.0   East         2019-09-09
# ..             ...             ...          ...    ...                ...
# 199       Danville      California      94526.0   West         2020-11-04
# 200    Springfield            Ohio      45503.0   East         2020-11-16
# 201   Philadelphia    Pennsylvania      19134.0   East         2020-12-03
# 202     Burlington  North Carolina      27217.0  South         2020-11-04
# 203        Seattle      Washington      98103.0   West         2020-11-09
#
#     date_diff  date_diff_days order_weekday ship_weekday
# 0      4 days               4        Friday      Tuesday
# 1      6 days               6       Tuesday       Monday
# 2      5 days               5     Wednesday       Monday
# 3      4 days               4      Thursday       Monday
# 4      3 days               3        Friday       Monday
# ..        ...             ...           ...          ...
# 199    2 days               2        Monday    Wednesday
# 200    3 days               3        Friday       Monday
# 201    3 days               3        Monday     Thursday
# 202    0 days               0     Wednesday    Wednesday
# 203    6 days               6       Tuesday       Monday
#
# [204 rows x 15 columns]

# %%
merged_metric_1 = merged_metric_1.query("order_weekday in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']")

# %%
merged_metric_1
# Out:
#             order id order date ship mode customer id country/region  \
# 1703  CA-2019-100244 2019-09-20  Standard    GM-14695  United States
# 1711  CA-2019-100944 2019-09-24  Standard    EH-13765  United States
# 1740  CA-2019-102162 2019-09-11  Standard    JF-15565  United States
# 1747  CA-2019-102932 2019-09-19  Standard    SD-20485  United States
# 1748  CA-2019-102981 2019-09-06  Standard    MO-17500  United States
# ...              ...        ...       ...         ...            ...
# 4984  US-2020-163790 2020-11-02  Standard    NL-18310  United States
# 4987  US-2020-165344 2020-11-13   Express    SB-20290  United States
# 4989  US-2020-165456 2020-11-30   Express    TB-21625  United States
# 5001  US-2020-168116 2020-11-04   Express    GT-14635  United States
# 5004  US-2020-168802 2020-11-03  Standard    JO-15145  United States
#
#                city           state  postal code region ready to ship date  \
# 1703  San Francisco      California      94122.0   West         2019-09-24
# 1711    Los Angeles      California      90049.0   West         2019-09-30
# 1740   Newport News        Virginia      23602.0  South         2019-09-16
# 1747         Orange      New Jersey       7050.0   East         2019-09-23
# 1748  New York City        New York      10035.0   East         2019-09-09
# ...             ...             ...          ...    ...                ...
# 4984       Danville      California      94526.0   West         2020-11-04
# 4987    Springfield            Ohio      45503.0   East         2020-11-16
# 4989   Philadelphia    Pennsylvania      19134.0   East         2020-12-03
# 5001     Burlington  North Carolina      27217.0  South         2020-11-04
# 5004        Seattle      Washington      98103.0   West         2020-11-09
#
#      date_diff  date_diff_days order_weekday ship_weekday
# 1703    4 days               4        Friday      Tuesday
# 1711    6 days               6       Tuesday       Monday
# 1740    5 days               5     Wednesday       Monday
# 1747    4 days               4      Thursday       Monday
# 1748    3 days               3        Friday       Monday
# ...        ...             ...           ...          ...
# 4984    2 days               2        Monday    Wednesday
# 4987    3 days               3        Friday       Monday
# 4989    3 days               3        Monday     Thursday
# 5001    0 days               0     Wednesday    Wednesday
# 5004    6 days               6       Tuesday       Monday
#
# [188 rows x 14 columns]

# %%
sample_mean_metric_1 = merged_metric_1['date_diff_days'].mean() 
sample_std_metric_1 = merged_metric_1['date_diff_days'].std() 
sample_median_metric_1 = merged_metric_1['date_diff_days'].median() 
n_metric_1 = len(merged_metric_1) 
print(f'n: {n_metric_1}')
print(f"Sample Mean: {sample_mean_metric_1:.2f}") 
print(f"Sample Standard Deviation: {sample_std_metric_1:.2f}") 
print(f"Sample Median: {sample_median_metric_1:.2f}")
# Out:
# n: 188
# Sample Mean: 4.15
# Sample Standard Deviation: 1.95
# Sample Median: 4.00

# %%
sns.histplot(merged_metric_1['date_diff_days'], kde=True)
plt.title("Distribution of O_date_2_processed")
plt.xlabel("Duration of O_date_2_processed")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(merged_metric_1['date_diff_days'])
plt.title("Distribution of O_date_2_processed")
plt.xlabel("Duration of O_date_2_processed")
plt.ylabel("Frequency")
plt.show()

# %%
merged_metric_1['date_diff_days'].skew() # Checking skewness value  well within the expected bounds of  -0.5 and +0.5
# Out:
# np.float64(-0.6045488661856514)

# %%
merged_metric_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 188 entries, 1703 to 5004
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order id            188 non-null    object
#  1   order date          188 non-null    datetime64[ns]
#  2   ship mode           188 non-null    object
#  3   customer id         188 non-null    object
#  4   country/region      188 non-null    object
#  5   city                188 non-null    object
#  6   state               188 non-null    object
#  7   postal code         188 non-null    float64
#  8   region              188 non-null    object
#  9   ready to ship date  188 non-null    datetime64[ns]
#  10  date_diff           188 non-null    timedelta64[ns]
#  11  date_diff_days      188 non-null    int64
#  12  order_weekday       188 non-null    object
#  13  ship_weekday        188 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(9), timedelta64[ns](1)
# memory usage: 22.0+ KB

# %% [markdown]
# ### in this situation, we should use bootstrapping method since the skewness is quite high

# %%
import numpy as np
from scipy import stats

# %%
# using bootstrapping: create a function

# Step 1: Calculate the sample petal length mean
sample_mean_metric_1 = merged_metric_1['date_diff_days'].mean()
print(f"Sample average duration of o_date_2_processed : {sample_mean_metric_1:.2f}")

# Step 2: Define a bootstrapping function to calculate the CI
def bootstrap_ci(data, n, num_bootstrap=10000, confidence_level=0.95):
    bootstrapped_means = []
    n=len(merged_metric_1)
    for _ in range(num_bootstrap):
        sample = np.random.choice(data, size=n, replace=True)
        bootstrapped_means.append(np.mean(sample))
    
    # CI bounds
    lower_bound = np.percentile(bootstrapped_means, (1 - confidence_level) / 2 * 100)
    upper_bound = np.percentile(bootstrapped_means, (1 + confidence_level) / 2 * 100)
    return lower_bound, upper_bound, bootstrapped_means

# Step 3: Run bootstrapping
ci_lower, ci_upper, bootstrapped_means = bootstrap_ci(merged_metric_1['date_diff_days'], n=n_metric_1, num_bootstrap=10000, confidence_level=0.95)

print(f"95% Confidence Interval for the duration of O_date_2_processed: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample average duration of o_date_2_processed : 4.15
# 95% Confidence Interval for the duration of O_date_2_processed: (3.87, 4.43)

# %%
# bootstrapped_means = [...]

mean_val = np.mean(bootstrapped_means)
median_val = np.median(bootstrapped_means)
ci_lower = np.percentile(bootstrapped_means, 2.5)
ci_upper = np.percentile(bootstrapped_means, 97.5)

# Increase plot size
g = sns.displot(bootstrapped_means, kde=True, height=6, aspect=1.5)

# Add mean, median, and CI lines
plt.axvline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='blue', linestyle='-.', label=f'Median: {median_val:.2f}')
plt.axvline(ci_lower, color='green', linestyle=':', label=f'CI Lower: {ci_lower:.2f}')
plt.axvline(ci_upper, color='green', linestyle=':', label=f'CI Upper: {ci_upper:.2f}')

# Move legend outside and make it bigger
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, markerscale=1.2)
plt.tight_layout()
plt.show()

# %%
#using z distribution
from scipy.stats import norm

z_score = norm.ppf(0.975) # Z-score since the data is normal and population params are known
margin_of_error = z_score * (sample_std_metric_1 / np.sqrt(n_metric_1)) 
ci_lower = sample_mean_metric_1 - margin_of_error
ci_upper = sample_mean_metric_1 + margin_of_error

print(f"95% Confidence Interval for the duration of O_date_2_processed: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# 95% Confidence Interval for the duration of O_date_2_processed: (3.87, 4.43)

# %%
# Sample statistics
sample_mean = sample_mean_metric_1
sample_std = sample_std_metric_1
sample_median = sample_median_metric_1
n_metric_1 = len(merged_metric_1)  # Sample size

# 95% Confidence Interval using Z-distribution
z_score = norm.ppf(0.975)
margin_of_error = z_score * (sample_std / np.sqrt(n_metric_1))
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

# Define x-range around the mean
x = np.linspace(sample_mean - 4*sample_std, sample_mean + 4*sample_std, 1000)
y = norm.pdf(x, loc=sample_mean, scale=sample_std)

# Plot the normal curve
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Normal Distribution', color='blue')

# Shade 95% confidence interval
plt.fill_between(x, y, where=(x >= ci_lower) & (x <= ci_upper), color='lightblue', alpha=0.5, label='95% CI')

# Mark mean and median
plt.axvline(sample_mean, color='green', linestyle='-', linewidth=2, label=f'Mean = {sample_mean:.2f}')
plt.axvline(sample_median, color='purple', linestyle='--', linewidth=2, label=f'Median = {sample_median:.2f}')

# Mark CI bounds
plt.axvline(ci_lower, color='red', linestyle='--', label=f'CI Lower = {ci_lower:.2f}')
plt.axvline(ci_upper, color='red', linestyle='--', label=f'CI Upper = {ci_upper:.2f}')

# Labels
plt.title('Normal Distribution with 95% Confidence Interval')
plt.xlabel('Duration of O_date_2_processed')
plt.ylabel('Probability Density')

# Legend outside
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 95% Confidence Interval: (3.87, 4.43)

# %%
# another way to calculate the ci_lower and ci_upper
data_metric_1 = merged_metric_1['date_diff_days'].dropna()  # drop missing values if any

# Sample statistics
mean_metric_1 = np.mean(data_metric_1)
sem_metric_1 = stats.sem(data_metric_1)   # Standard error of the mean

# 95% confidence interval
ci = stats.norm.interval(confidence=0.95, loc=mean_metric_1, scale=sem_metric_1)
print("Mean:", mean_metric_1)
print("95% CI:", ci)
print("Sem", sem_metric_1)
# Out:
# Mean: 4.148936170212766
# 95% CI: (np.float64(3.870043922876699), np.float64(4.427828417548833))
# Sem 0.14229457762282027

# %%
#using t distribution

from scipy import stats

df = n_metric_1
t_crit = stats.t.ppf(0.975, df).round(2)
print(f't_cri: {t_crit}')

# t-critical value for 95% confidence
t_crit = stats.t.ppf(0.975, df=n_metric_1-1)

# Margin of error
margin_error = t_crit * (sample_std_metric_1 / np.sqrt(n_metric_1))

# Confidence interval
ci_lower = sample_mean - margin_error
ci_upper = sample_mean + margin_error

print(f"95% Confidence Interval for the duration of O_date_2_processed:({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# t_cri: 1.97
# 95% Confidence Interval for the duration of O_date_2_processed:(3.87, 4.43)

# %%
# Sample statistics
sample_mean = sample_mean_metric_1
sample_std = sample_std_metric_1
sample_median = sample_median_metric_1
n_metric_1 = len(merged_metric_1)
df = n_metric_1 - 1  # degrees of freedom

# Standard error
SE = sample_std / np.sqrt(n_metric_1)

# t-critical value for 95% confidence
t_crit = stats.t.ppf(0.975, df=df)

# Margin of error
margin_error = t_crit * SE

# Confidence interval
ci_lower = sample_mean - margin_error
ci_upper = sample_mean + margin_error
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

# Define x-range around the mean
x = np.linspace(sample_mean - 4*SE, sample_mean + 4*SE, 1000)

# Correctly scaled t-distribution PDF
y = stats.t.pdf((x - sample_mean) / SE, df=df) / SE

# Plot the t-distribution curve
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='t-Distribution', color='blue')

# Shade 95% confidence interval
plt.fill_between(x, y, where=(x >= ci_lower) & (x <= ci_upper), color='lightblue', alpha=0.5, label='95% CI')

# Mark mean
plt.axvline(sample_mean, color='green', linestyle='-', linewidth=2, label=f'Mean = {sample_mean:.2f}')

# Mark median
plt.axvline(sample_median, color='purple', linestyle='-.', linewidth=2, label=f'Median = {sample_median:.2f}')

# Mark CI bounds
plt.axvline(ci_lower, color='red', linestyle='--', label=f'CI Lower = {ci_lower:.2f}')
plt.axvline(ci_upper, color='red', linestyle='--', label=f'CI Upper = {ci_upper:.2f}')

# Labels
plt.title('t-Distribution with 95% Confidence Interval')
plt.xlabel('Duration of O_date_2_processed')
plt.ylabel('Probability Density')

# Legend outside
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 95% Confidence Interval: (3.87, 4.43)

# %% [markdown]
# ###  KPI: O_processes_2_truck

# %%
df_processed_x_truck_smode
# Out:
#            order id on truck scan date ready to ship date  \
# 0    CA-2019-116540         2019-09-03         2019-09-02
# 1    CA-2019-129847         2019-09-04         2019-09-04
# 2    CA-2019-129630         2019-09-04         2019-09-04
# 3    CA-2019-158099         2019-09-06         2019-09-05
# 4    CA-2019-132143         2019-09-06         2019-09-05
# ..              ...                ...                ...
# 199  CA-2020-159506         2020-12-04         2020-12-02
# 200  US-2020-110576         2020-12-07         2020-12-04
# 201  CA-2020-119305         2020-12-07         2020-12-04
# 202  CA-2020-105333         2020-12-07         2020-12-04
# 203  CA-2020-142090         2020-12-09         2020-12-07
#
#      ready to ship date_weekday ship mode order date  \
# 0                             0   Express 2019-09-02
# 1                             2   Express 2019-09-02
# 2                             2   Express 2019-09-04
# 3                             3   Express 2019-09-03
# 4                             3   Express 2019-09-03
# ..                          ...       ...        ...
# 199                           2  Standard 2020-11-27
# 200                           4  Standard 2020-11-28
# 201                           4  Standard 2020-11-30
# 202                           4  Standard 2020-11-30
# 203                           0  Standard 2020-11-30
#
#      o_processed_2_truck_actual order date_weekday
# 0                             1             Monday
# 1                             0             Monday
# 2                             0          Wednesday
# 3                             1            Tuesday
# 4                             1            Tuesday
# ..                          ...                ...
# 199                           2             Friday
# 200                           3           Saturday
# 201                           3             Monday
# 202                           3             Monday
# 203                           2             Monday
#
# [204 rows x 8 columns]

# %%
df_processed_x_truck_smode['o_processed_2_truck_actual'].value_counts()
# Out:
# o_processed_2_truck_actual
# 2    82
# 1    55
# 3    34
# 0    33
# Name: count, dtype: int64

# %%
df_processed_x_truck_smode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   order id                    204 non-null    object
#  1   on truck scan date          204 non-null    datetime64[ns]
#  2   ready to ship date          204 non-null    datetime64[ns]
#  3   ready to ship date_weekday  204 non-null    int32
#  4   ship mode                   204 non-null    object
#  5   order date                  204 non-null    datetime64[ns]
#  6   o_processed_2_truck_actual  204 non-null    int64
#  7   order date_weekday          204 non-null    object
# dtypes: datetime64[ns](3), int32(1), int64(1), object(3)
# memory usage: 12.1+ KB

# %%
df_processed_x_truck_smode = df_processed_x_truck_smode.query(
    "`order date_weekday` in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']"
)

# %%
df_processed_x_truck_smode
# Out:
#            order id on truck scan date ready to ship date  \
# 0    CA-2019-116540         2019-09-03         2019-09-02
# 1    CA-2019-129847         2019-09-04         2019-09-04
# 2    CA-2019-129630         2019-09-04         2019-09-04
# 3    CA-2019-158099         2019-09-06         2019-09-05
# 4    CA-2019-132143         2019-09-06         2019-09-05
# ..              ...                ...                ...
# 198  CA-2020-107125         2020-12-04         2020-12-02
# 199  CA-2020-159506         2020-12-04         2020-12-02
# 201  CA-2020-119305         2020-12-07         2020-12-04
# 202  CA-2020-105333         2020-12-07         2020-12-04
# 203  CA-2020-142090         2020-12-09         2020-12-07
#
#      ready to ship date_weekday ship mode order date  \
# 0                             0   Express 2019-09-02
# 1                             2   Express 2019-09-02
# 2                             2   Express 2019-09-04
# 3                             3   Express 2019-09-03
# 4                             3   Express 2019-09-03
# ..                          ...       ...        ...
# 198                           2  Standard 2020-11-27
# 199                           2  Standard 2020-11-27
# 201                           4  Standard 2020-11-30
# 202                           4  Standard 2020-11-30
# 203                           0  Standard 2020-11-30
#
#      o_processed_2_truck_actual order date_weekday
# 0                             1             Monday
# 1                             0             Monday
# 2                             0          Wednesday
# 3                             1            Tuesday
# 4                             1            Tuesday
# ..                          ...                ...
# 198                           2             Friday
# 199                           2             Friday
# 201                           3             Monday
# 202                           3             Monday
# 203                           2             Monday
#
# [188 rows x 8 columns]

# %%
sample_mean_metric_2 = df_processed_x_truck_smode['o_processed_2_truck_actual'].mean() 
sample_std_metric_2 = df_processed_x_truck_smode['o_processed_2_truck_actual'].std() 
sample_median_metric_2 = df_processed_x_truck_smode['o_processed_2_truck_actual'].median() 
n_metric_2 = len(df_processed_x_truck_smode) 
print(f"Sample Mean: {sample_mean_metric_2:.2f}") 
print(f"Sample Standard Deviation: {sample_std_metric_2:.2f}") 
print(f"Sample Median: {sample_median_metric_2:.2f}")
# Out:
# Sample Mean: 1.54
# Sample Standard Deviation: 0.93
# Sample Median: 2.00

# %%
sns.histplot(df_processed_x_truck_smode['o_processed_2_truck_actual'], kde=True)
plt.title("Distribution of the sample average duration of O_processes_2_truck")
plt.xlabel("Duration of O_processes_2_truck")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(df_processed_x_truck_smode['o_processed_2_truck_actual'])
plt.title("Distribution of the sample average duration of O_date_2_processed")
plt.xlabel("Duration of O_date_2_processed")
plt.ylabel("Frequency")
plt.show()

# %%
df_processed_x_truck_smode['o_processed_2_truck_actual'].skew() # Checking skewness value  well within the expected bounds of  -0.5 and +0.5
# Out:
# np.float64(-0.1893330449961753)

# %%
df_processed_x_truck_smode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 188 entries, 0 to 203
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   order id                    188 non-null    object
#  1   on truck scan date          188 non-null    datetime64[ns]
#  2   ready to ship date          188 non-null    datetime64[ns]
#  3   ready to ship date_weekday  188 non-null    int32
#  4   ship mode                   188 non-null    object
#  5   order date                  188 non-null    datetime64[ns]
#  6   o_processed_2_truck_actual  188 non-null    int64
#  7   order date_weekday          188 non-null    object
# dtypes: datetime64[ns](3), int32(1), int64(1), object(3)
# memory usage: 12.5+ KB

# %% [markdown]
# ### in this case, use normal distribution would be better, since the sample size is 188, we should adopt z distribution

# %%
#using z distribution
from scipy.stats import norm

z_score = norm.ppf(0.975) # Z-score since the data is normal and population params are known
margin_of_error = z_score * (sample_std_metric_2 / np.sqrt(n_metric_2))  
ci_lower = sample_mean_metric_2 - margin_of_error
ci_upper = sample_mean_metric_2 + margin_of_error

print(f"95% Confidence Interval for the duration of o_processed_2_truck: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# 95% Confidence Interval for the duration of o_processed_2_truck: (1.40, 1.67)

# %%
# Sample statistics
sample_mean = sample_mean_metric_2
sample_std = sample_std_metric_2
sample_median = sample_median_metric_2
n_metric_2 = len(df_processed_x_truck_smode)  # Sample size

# 95% Confidence Interval using Z-distribution
z_score = norm.ppf(0.975)
margin_of_error = z_score * (sample_std / np.sqrt(n_metric_2))
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

# Define x-range around the mean
x = np.linspace(sample_mean - 4*sample_std, sample_mean + 4*sample_std, 1000)
y = norm.pdf(x, loc=sample_mean, scale=sample_std)

# Plot the normal curve
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Normal Distribution', color='blue')

# Shade 95% confidence interval
plt.fill_between(x, y, where=(x >= ci_lower) & (x <= ci_upper), color='lightblue', alpha=0.5, label='95% CI')

# Mark mean and median
plt.axvline(sample_mean, color='green', linestyle='-', linewidth=2, label=f'Mean = {sample_mean:.2f}')
plt.axvline(sample_median, color='purple', linestyle='--', linewidth=2, label=f'Median = {sample_median:.2f}')

# Mark CI bounds
plt.axvline(ci_lower, color='red', linestyle='--', label=f'CI Lower = {ci_lower:.2f}')
plt.axvline(ci_upper, color='red', linestyle='--', label=f'CI Upper = {ci_upper:.2f}')

# Labels
plt.title('Normal Distribution with 95% Confidence Interval')
plt.xlabel('Duration of O_date_2_processed')
plt.ylabel('Probability Density')

# Legend outside
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 95% Confidence Interval: (1.40, 1.67)

# %%
# another way to calculate the ci_lower and ci_upper
data_metric_2 = df_processed_x_truck_smode['o_processed_2_truck_actual'].dropna()  # drop missing values if any

# Sample statistics
mean_metric_2 = np.mean(data_metric_2)
sem_metric_2 = stats.sem(data_metric_2)   # Standard error of the mean

# 95% confidence interval
ci = stats.norm.interval(confidence=0.95, loc=mean_metric_2, scale=sem_metric_2)
print("Mean:", mean_metric_2)
print("95% CI:", ci)
print("Sem", sem_metric_2)
# Out:
# Mean: 1.5372340425531914
# 95% CI: (np.float64(1.4038835367711342), np.float64(1.6705845483352486))
# Sem 0.06803722253771445

# %%
#using t distribution

from scipy import stats

df = n_metric_2
t_crit = stats.t.ppf(0.975, df).round(2)
print(f't_cri: {t_crit}')

# t-critical value for 95% confidence
t_crit = stats.t.ppf(0.975, df=n_metric_2-1)

# Margin of error
margin_error = t_crit * (sample_std_metric_2 / np.sqrt(n_metric_2))

# Confidence interval
ci_lower = sample_mean_metric_2 - margin_error
ci_upper = sample_mean_metric_2 + margin_error

print(f"95% Confidence Interval of the duration of o_processed_2_truck: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# t_cri: 1.97
# 95% Confidence Interval of the duration of o_processed_2_truck: (1.40, 1.67)

# %%
# Sample statistics
sample_mean = sample_mean_metric_2
sample_std = sample_std_metric_2
sample_median = sample_median_metric_2
n_metric_2 = len(df_processed_x_truck_smode)  # Sample size
df = n_metric_2 - 1  # degrees of freedom

# Standard error
SE = sample_std / np.sqrt(n_metric_2)

# t-critical value for 95% confidence
t_crit = stats.t.ppf(0.975, df=df)

# Margin of error
margin_error = t_crit * SE

# Confidence interval
ci_lower = sample_mean - margin_error
ci_upper = sample_mean + margin_error
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

# Define x-range around the mean
x = np.linspace(sample_mean - 4*SE, sample_mean + 4*SE, 1000)

# Correctly scaled t-distribution PDF
y = stats.t.pdf((x - sample_mean) / SE, df=df) / SE

# Plot the t-distribution curve
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='t-Distribution', color='blue')

# Shade 95% confidence interval
plt.fill_between(x, y, where=(x >= ci_lower) & (x <= ci_upper), color='lightblue', alpha=0.5, label='95% CI')

# Mark mean
plt.axvline(sample_mean, color='green', linestyle='-', linewidth=2, label=f'Mean = {sample_mean:.2f}')

# Mark median
plt.axvline(sample_median, color='purple', linestyle='-.', linewidth=2, label=f'Median = {sample_median:.2f}')

# Mark CI bounds
plt.axvline(ci_lower, color='red', linestyle='--', label=f'CI Lower = {ci_lower:.2f}')
plt.axvline(ci_upper, color='red', linestyle='--', label=f'CI Upper = {ci_upper:.2f}')

# Labels
plt.title('t-Distribution with 95% Confidence Interval')
plt.xlabel('Duration of O_date_2_processed')
plt.ylabel('Probability Density')

# Legend outside
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 95% Confidence Interval: (1.40, 1.67)

# %%
# using bootstrapping: create a function

# Step 1: Calculate the sample petal length mean
sample_mean_metric_2 = df_processed_x_truck_smode['o_processed_2_truck_actual'].mean()
print(f"Sample average duration of o_processed_2_truck : {sample_mean_metric_2:.2f}")

# Step 2: Define a bootstrapping function to calculate the CI
def bootstrap_ci(data, n, num_bootstrap=10000, confidence_level=0.95):
    bootstrapped_means = []
    n=len(df_processed_x_truck_smode)
    for _ in range(num_bootstrap):
        sample = np.random.choice(data, size=n, replace=True)
        bootstrapped_means.append(np.mean(sample))
    
    # CI bounds
    lower_bound = np.percentile(bootstrapped_means, (1 - confidence_level) / 2 * 100)
    upper_bound = np.percentile(bootstrapped_means, (1 + confidence_level) / 2 * 100)
    return lower_bound, upper_bound, bootstrapped_means

# Step 3: Run bootstrapping
ci_lower, ci_upper, bootstrapped_means = bootstrap_ci(df_processed_x_truck_smode['o_processed_2_truck_actual'], n=n_metric_2, num_bootstrap=1000, confidence_level=0.95)

print(f"95% Confidence Interval for the duration of o_processed_2_truck: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample average duration of o_processed_2_truck : 1.54
# 95% Confidence Interval for the duration of o_processed_2_truck: (1.40, 1.67)

# %%
# bootstrapped_means = [...]

mean_val = np.mean(bootstrapped_means)
median_val = np.median(bootstrapped_means)
ci_lower = np.percentile(bootstrapped_means, 2.5)
ci_upper = np.percentile(bootstrapped_means, 97.5)

# Increase plot size
g = sns.displot(bootstrapped_means, kde=True, height=6, aspect=1.5)

# Add mean, median, and CI lines
plt.axvline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='blue', linestyle='-.', label=f'Median: {median_val:.2f}')
plt.axvline(ci_lower, color='green', linestyle=':', label=f'CI Lower: {ci_lower:.2f}')
plt.axvline(ci_upper, color='green', linestyle=':', label=f'CI Upper: {ci_upper:.2f}')

# Move legend outside and make it bigger
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, markerscale=1.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  KPI: O_truck_2_delivered

# %%
merged_o_truck_2_delivered
# Out:
#            order id arrival scan date on truck scan date ship mode  \
# 0    CA-2019-109666        2019-05-03         2019-04-29  Standard
# 1    CA-2019-138933        2019-05-03         2019-04-29   Express
# 2    CA-2019-130001        2019-05-03         2019-05-01  Standard
# 3    CA-2019-113061        2019-05-06         2019-04-29  Standard
# 4    CA-2019-162138        2019-05-06         2019-05-01  Standard
# ..              ...               ...                ...       ...
# 328  CA-2020-129707        2020-05-08         2020-05-04  Standard
# 329  CA-2020-125381        2020-05-08         2020-05-01  Standard
# 330  CA-2020-141733        2020-05-15         2020-05-13  Standard
# 331  US-2020-104451        2020-05-15         2020-05-13  Standard
# 332  US-2020-139647        2020-05-15         2020-05-13   Express
#
#     time interval  arrival year  arrival month arrival day  on truck year  \
# 0          4 days          2019              5      friday           2019
# 1          4 days          2019              5      friday           2019
# 2          2 days          2019              5      friday           2019
# 3          7 days          2019              5      monday           2019
# 4          5 days          2019              5      monday           2019
# ..            ...           ...            ...         ...            ...
# 328        4 days          2020              5      friday           2020
# 329        7 days          2020              5      friday           2020
# 330        2 days          2020              5      friday           2020
# 331        2 days          2020              5      friday           2020
# 332        2 days          2020              5      friday           2020
#
#      on truck month on truck day  actual duration
# 0                 4       monday                4
# 1                 4       monday                4
# 2                 5    wednesday                2
# 3                 4       monday                7
# 4                 5    wednesday                5
# ..              ...          ...              ...
# 328               5       monday                4
# 329               5       friday                7
# 330               5    wednesday                2
# 331               5    wednesday                2
# 332               5    wednesday                2
#
# [333 rows x 12 columns]

# %%
merged_o_truck_2_delivered['on truck day'] = merged_o_truck_2_delivered['on truck day'].replace({
    'monday': 'Monday',
    'tuesday': 'Tuesday',
    'wednesday': 'Wed',
    'thursday': 'Thursday',
    'friday': 'Friday'
})

# %%
merged_o_truck_2_delivered = merged_o_truck_2_delivered.query(
    "`on truck day` in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']"
)

# %%
merged_o_truck_2_delivered
# Out:
#            order id arrival scan date on truck scan date ship mode  \
# 0    CA-2019-109666        2019-05-03         2019-04-29  Standard
# 1    CA-2019-138933        2019-05-03         2019-04-29   Express
# 3    CA-2019-113061        2019-05-06         2019-04-29  Standard
# 8    CA-2019-146836        2019-05-06         2019-05-03   Express
# 12   CA-2019-161816        2019-05-07         2019-05-03   Express
# ..              ...               ...                ...       ...
# 324  CA-2020-135076        2020-04-27         2020-04-20  Standard
# 326  CA-2020-140802        2020-04-27         2020-04-24   Express
# 327  CA-2020-134845        2020-04-30         2020-04-24  Standard
# 328  CA-2020-129707        2020-05-08         2020-05-04  Standard
# 329  CA-2020-125381        2020-05-08         2020-05-01  Standard
#
#     time interval  arrival year  arrival month arrival day  on truck year  \
# 0          4 days          2019              5      friday           2019
# 1          4 days          2019              5      friday           2019
# 3          7 days          2019              5      monday           2019
# 8          3 days          2019              5      monday           2019
# 12         4 days          2019              5     tuesday           2019
# ..            ...           ...            ...         ...            ...
# 324        7 days          2020              4      monday           2020
# 326        3 days          2020              4      monday           2020
# 327        6 days          2020              4    thursday           2020
# 328        4 days          2020              5      friday           2020
# 329        7 days          2020              5      friday           2020
#
#      on truck month on truck day  actual duration
# 0                 4       Monday                4
# 1                 4       Monday                4
# 3                 4       Monday                7
# 8                 5       Friday                3
# 12                5       Friday                4
# ..              ...          ...              ...
# 324               4       Monday                7
# 326               4       Friday                3
# 327               4       Friday                6
# 328               5       Monday                4
# 329               5       Friday                7
#
# [134 rows x 12 columns]

# %%
merged_o_truck_2_delivered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 134 entries, 0 to 329
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order id            134 non-null    object
#  1   arrival scan date   134 non-null    datetime64[ns]
#  2   on truck scan date  134 non-null    datetime64[ns]
#  3   ship mode           134 non-null    object
#  4   time interval       134 non-null    timedelta64[ns]
#  5   arrival year        134 non-null    int32
#  6   arrival month       134 non-null    int32
#  7   arrival day         134 non-null    object
#  8   on truck year       134 non-null    int32
#  9   on truck month      134 non-null    int32
#  10  on truck day        134 non-null    object
#  11  actual duration     134 non-null    int64
# dtypes: datetime64[ns](2), int32(4), int64(1), object(4), timedelta64[ns](1)
# memory usage: 11.5+ KB

# %%
sample_mean_metric_3 = merged_o_truck_2_delivered['actual duration'].mean() 
sample_std_metric_3 = merged_o_truck_2_delivered['actual duration'].std() 
sample_median_metric_3 = merged_o_truck_2_delivered['actual duration'].median() 
n_metric_3 = len(merged_o_truck_2_delivered) 
print(f"Sample Mean: {sample_mean_metric_3:.2f}") 
print(f"Sample Standard Deviation: {sample_std_metric_3:.2f}") 
print(f"Sample Median: {sample_median_metric_3:.2f}")
# Out:
# Sample Mean: 4.26
# Sample Standard Deviation: 1.41
# Sample Median: 4.00

# %%
sns.histplot(merged_o_truck_2_delivered['actual duration'], kde=True)
plt.title("Distribution of sample average duration of o_truck_2_delivered")
plt.xlabel("Duration of O_truck_2_delivered")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(merged_o_truck_2_delivered['actual duration'])
plt.title("Distribution of sample average duration of O_truck_2_delivered")
plt.xlabel("Duration of O_truck_2_delivered")
plt.ylabel("Frequency")
plt.show()

# %%
merged_o_truck_2_delivered['actual duration'].skew() # Checking skewness value  well within the expected bounds of  -0.5 and +0.5
# Out:
# np.float64(0.720726458875498)

# %%
merged_o_truck_2_delivered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 134 entries, 0 to 329
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order id            134 non-null    object
#  1   arrival scan date   134 non-null    datetime64[ns]
#  2   on truck scan date  134 non-null    datetime64[ns]
#  3   ship mode           134 non-null    object
#  4   time interval       134 non-null    timedelta64[ns]
#  5   arrival year        134 non-null    int32
#  6   arrival month       134 non-null    int32
#  7   arrival day         134 non-null    object
#  8   on truck year       134 non-null    int32
#  9   on truck month      134 non-null    int32
#  10  on truck day        134 non-null    object
#  11  actual duration     134 non-null    int64
# dtypes: datetime64[ns](2), int32(4), int64(1), object(4), timedelta64[ns](1)
# memory usage: 11.5+ KB

# %% [markdown]
# ### in this case, the skewness is within the range, therefore we can use normal distribution would be better, since the sample size is 334, we should adopt z distribution

# %%
#using z distribution
from scipy.stats import norm

z_score = norm.ppf(0.975) # Z-score since the data is normal and population params are known
margin_of_error = z_score * (sample_std_metric_3/ np.sqrt(n_metric_3))  
ci_lower = sample_mean_metric_3 - margin_of_error
ci_upper = sample_mean_metric_3 + margin_of_error

print(f"95% Confidence Interval for the duration of O_truck_2_delivered: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# 95% Confidence Interval for the duration of O_truck_2_delivered: (4.02, 4.50)

# %%
# Sample statistics
sample_mean = sample_mean_metric_3
sample_std = sample_std_metric_3
sample_median = sample_median_metric_3
n_metric_3 = len(merged_o_truck_2_delivered)  # Sample size

# 95% Confidence Interval using Z-distribution
z_score = norm.ppf(0.975)
margin_of_error = z_score * (sample_std / np.sqrt(n_metric_3))
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

# Define x-range around the mean
x = np.linspace(sample_mean - 4*sample_std, sample_mean + 4*sample_std, 1000)
y = norm.pdf(x, loc=sample_mean, scale=sample_std)

# Plot the normal curve
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Normal Distribution', color='blue')

# Shade 95% confidence interval
plt.fill_between(x, y, where=(x >= ci_lower) & (x <= ci_upper), color='lightblue', alpha=0.5, label='95% CI')

# Mark mean and median
plt.axvline(sample_mean, color='green', linestyle='-', linewidth=2, label=f'Mean = {sample_mean:.2f}')
plt.axvline(sample_median, color='purple', linestyle='--', linewidth=2, label=f'Median = {sample_median:.2f}')

# Mark CI bounds
plt.axvline(ci_lower, color='red', linestyle='--', label=f'CI Lower = {ci_lower:.2f}')
plt.axvline(ci_upper, color='red', linestyle='--', label=f'CI Upper = {ci_upper:.2f}')

# Labels
plt.title('Normal Distribution with 95% Confidence Interval')
plt.xlabel('Duration of O_date_2_processed')
plt.ylabel('Probability Density')

# Legend outside
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 95% Confidence Interval: (4.02, 4.50)

# %%
# another way to calculate the ci_lower and ci_upper
data_metric_3 = merged_o_truck_2_delivered['actual duration'].dropna()  # drop missing values if any

# Sample statistics
mean_metric_3 = np.mean(data_metric_3)
sem_metric_3 = stats.sem(data_metric_3)   # Standard error of the mean

# 95% confidence interval
ci = stats.norm.interval(confidence=0.95, loc=mean_metric_3, scale=sem_metric_3)
print("Mean:", mean_metric_3)
print("95% CI:", ci)
print("Sem", sem_metric_3)
# Out:
# Mean: 4.2611940298507465
# 95% CI: (np.float64(4.022712265294652), np.float64(4.499675794406841))
# Sem 0.12167660550765616

# %%
# Sample statistics
sample_mean = sample_mean_metric_3
sample_std = sample_std_metric_3
sample_median = sample_median_metric_3
n_metric_3 = len(merged_o_truck_2_delivered)  # Sample size
df = n_metric_3 - 1  # degrees of freedom

# Standard error
SE = sample_std / np.sqrt(n_metric_3)

# t-critical value for 95% confidence
t_crit = stats.t.ppf(0.975, df=df)

# Margin of error
margin_error = t_crit * SE

# Confidence interval
ci_lower = sample_mean - margin_error
ci_upper = sample_mean + margin_error
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

# Define x-range around the mean
x = np.linspace(sample_mean - 4*SE, sample_mean + 4*SE, 1000)

# Correctly scaled t-distribution PDF
y = stats.t.pdf((x - sample_mean) / SE, df=df) / SE

# Plot the t-distribution curve
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='t-Distribution', color='blue')

# Shade 95% confidence interval
plt.fill_between(x, y, where=(x >= ci_lower) & (x <= ci_upper), color='lightblue', alpha=0.5, label='95% CI')

# Mark mean
plt.axvline(sample_mean, color='green', linestyle='-', linewidth=2, label=f'Mean = {sample_mean:.2f}')

# Mark median
plt.axvline(sample_median, color='purple', linestyle='-.', linewidth=2, label=f'Median = {sample_median:.2f}')

# Mark CI bounds
plt.axvline(ci_lower, color='red', linestyle='--', label=f'CI Lower = {ci_lower:.2f}')
plt.axvline(ci_upper, color='red', linestyle='--', label=f'CI Upper = {ci_upper:.2f}')

# Labels
plt.title('t-Distribution with 95% Confidence Interval')
plt.xlabel('Duration of O_date_2_processed')
plt.ylabel('Probability Density')

# Legend outside
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 95% Confidence Interval: (4.02, 4.50)

# %%
# using bootstrapping: create a function

# Step 1: Calculate the sample petal length mean
sample_mean_metric_3 = merged_o_truck_2_delivered['actual duration'].mean()
print(f"Sample average duration of o_truck_2_delivered : {sample_mean_metric_3:.2f}")

# Step 2: Define a bootstrapping function to calculate the CI
def bootstrap_ci(data, n, num_bootstrap=10000, confidence_level=0.95):
    bootstrapped_means = []
    n=len(merged_o_truck_2_delivered)
    for _ in range(num_bootstrap):
        sample = np.random.choice(data, size=n, replace=True)
        bootstrapped_means.append(np.mean(sample))
    
    # CI bounds
    lower_bound = np.percentile(bootstrapped_means, (1 - confidence_level) / 2 * 100)
    upper_bound = np.percentile(bootstrapped_means, (1 + confidence_level) / 2 * 100)
    return lower_bound, upper_bound, bootstrapped_means

# Step 3: Run bootstrapping
ci_lower, ci_upper, bootstrapped_means = bootstrap_ci(merged_o_truck_2_delivered['actual duration'], n=n_metric_3, num_bootstrap=10000, confidence_level=0.95)

print(f"95% Confidence Interval for the duration of O_truck_2_delivered: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample average duration of o_truck_2_delivered : 4.26
# 95% Confidence Interval for the duration of O_truck_2_delivered: (4.03, 4.50)

# %%
# bootstrapped_means = [...]

mean_val = np.mean(bootstrapped_means)
median_val = np.median(bootstrapped_means)
ci_lower = np.percentile(bootstrapped_means, 2.5)
ci_upper = np.percentile(bootstrapped_means, 97.5)

# Increase plot size
g = sns.displot(bootstrapped_means, kde=True, height=6, aspect=1.5)

# Add mean, median, and CI lines
plt.axvline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='blue', linestyle='-.', label=f'Median: {median_val:.2f}')
plt.axvline(ci_lower, color='green', linestyle=':', label=f'CI Lower: {ci_lower:.2f}')
plt.axvline(ci_upper, color='green', linestyle=':', label=f'CI Upper: {ci_upper:.2f}')

# Move legend outside and make it bigger
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, markerscale=1.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  KPI: O_date_2_delivered

# %%
merged_metric_2.reset_index()
# Out:
#      index        order id order date ship mode customer id country/region  \
# 0     1699  CA-2019-100041 2019-11-20  Standard    BF-10975  United States
# 1     1700  CA-2019-100083 2019-11-24  Standard    CD-11980  United States
# 2     1703  CA-2019-100244 2019-09-20  Standard    GM-14695  United States
# 3     1706  CA-2019-100468 2019-11-24  Standard    AT-10435  United States
# 4     1707  CA-2019-100510 2019-05-12  Standard    HM-14860  United States
# ..     ...             ...        ...       ...         ...            ...
# 328   4897  US-2020-139647 2020-05-11   Express    TS-21370  United States
# 329   4931  US-2020-148551 2020-01-12  Standard    DB-13120  United States
# 330   4965  US-2020-158512 2020-01-12  Standard    DA-13450  United States
# 331   4981  US-2020-163195 2020-02-17  Standard    LL-16840  United States
# 332   5003  US-2020-168690 2020-01-07  Standard    TS-21085  United States
#
#               city                 state  postal code   region  \
# 0         Columbus               Indiana      47201.0  Central
# 1          Medford                Oregon      97504.0     West
# 2    San Francisco            California      94122.0     West
# 3      Los Angeles            California      90045.0     West
# 4    New York City              New York      10024.0     East
# ..             ...                   ...          ...      ...
# 328        Phoenix               Arizona      85023.0     West
# 329         Dallas                 Texas      75217.0  Central
# 330     Washington  District of Columbia      20016.0     East
# 331      Lafayette             Louisiana      70506.0    South
# 332   Ormond Beach               Florida      32174.0    South
#
#     arrival scan date date_diff  date_diff_days order_weekday arrival_weekday
# 0          2019-12-02   12 days              12     Wednesday          Monday
# 1          2019-12-09   15 days              15        Sunday          Monday
# 2          2019-09-30   10 days              10        Friday          Monday
# 3          2019-12-09   15 days              15        Sunday          Monday
# 4          2019-05-28   16 days              16        Sunday         Tuesday
# ..                ...       ...             ...           ...             ...
# 328        2020-05-15    4 days               4        Monday          Friday
# 329        2020-01-22   10 days              10        Sunday       Wednesday
# 330        2020-01-27   15 days              15        Sunday          Monday
# 331        2020-03-02   14 days              14        Monday          Monday
# 332        2020-01-20   13 days              13       Tuesday          Monday
#
# [333 rows x 15 columns]

# %%
merged_metric_2 = merged_metric_2.query(
    "`order_weekday` in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']"
)

# %%
merged_metric_2
# Out:
#             order id order date ship mode customer id country/region  \
# 1699  CA-2019-100041 2019-11-20  Standard    BF-10975  United States
# 1703  CA-2019-100244 2019-09-20  Standard    GM-14695  United States
# 1708  CA-2019-100587 2019-12-10  Standard    SL-20155  United States
# 1715  CA-2019-101168 2019-12-25  Standard    SS-20140  United States
# 1717  CA-2019-101329 2019-04-22  Standard    MM-17920  United States
# ...              ...        ...       ...         ...            ...
# 4741  US-2020-104451 2020-05-08  Standard    MM-18055  United States
# 4894  US-2020-138086 2020-04-16  Standard    JO-15550  United States
# 4897  US-2020-139647 2020-05-11   Express    TS-21370  United States
# 4981  US-2020-163195 2020-02-17  Standard    LL-16840  United States
# 5003  US-2020-168690 2020-01-07  Standard    TS-21085  United States
#
#                city          state  postal code   region arrival scan date  \
# 1699       Columbus        Indiana      47201.0  Central        2019-12-02
# 1703  San Francisco     California      94122.0     West        2019-09-30
# 1708  New York City       New York      10024.0     East        2019-12-23
# 1715         Nashua  New Hampshire       3060.0     East        2020-01-07
# 1717           Rome       New York      13440.0     East        2019-05-08
# ...             ...            ...          ...      ...               ...
# 4741  San Francisco     California      94110.0     West        2020-05-15
# 4894  San Francisco     California      94109.0     West        2020-04-27
# 4897        Phoenix        Arizona      85023.0     West        2020-05-15
# 4981      Lafayette      Louisiana      70506.0    South        2020-03-02
# 5003   Ormond Beach        Florida      32174.0    South        2020-01-20
#
#      date_diff  date_diff_days order_weekday arrival_weekday
# 1699   12 days              12     Wednesday          Monday
# 1703   10 days              10        Friday          Monday
# 1708   13 days              13       Tuesday          Monday
# 1715   13 days              13     Wednesday         Tuesday
# 1717   16 days              16        Monday       Wednesday
# ...        ...             ...           ...             ...
# 4741    7 days               7        Friday          Friday
# 4894   11 days              11      Thursday          Monday
# 4897    4 days               4        Monday          Friday
# 4981   14 days              14        Monday          Monday
# 5003   13 days              13       Tuesday          Monday
#
# [261 rows x 14 columns]

# %%
merged_metric_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261 entries, 1699 to 5003
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order id           261 non-null    object
#  1   order date         261 non-null    datetime64[ns]
#  2   ship mode          261 non-null    object
#  3   customer id        261 non-null    object
#  4   country/region     261 non-null    object
#  5   city               261 non-null    object
#  6   state              261 non-null    object
#  7   postal code        261 non-null    float64
#  8   region             261 non-null    object
#  9   arrival scan date  261 non-null    datetime64[ns]
#  10  date_diff          261 non-null    timedelta64[ns]
#  11  date_diff_days     261 non-null    int64
#  12  order_weekday      261 non-null    object
#  13  arrival_weekday    261 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(9), timedelta64[ns](1)
# memory usage: 30.6+ KB

# %%
sample_mean_metric_4 = merged_metric_2['date_diff_days'].mean() 
sample_std_metric_4 = merged_metric_2['date_diff_days'].std() 
sample_median_metric_4 = merged_metric_2['date_diff_days'].median() 
n_metric_4 = len(merged_metric_2) 
print(f"Sample Mean: {sample_mean:.2f}") 
print(f"Sample Standard Deviation: {sample_std_metric_4 :.2f}") 
print(f"Sample Median: {sample_median_metric_4 :.2f}")
# Out:
# Sample Mean: 4.26
# Sample Standard Deviation: 2.76
# Sample Median: 11.00

# %%
sns.histplot(merged_metric_2['date_diff_days'], kde=True)
plt.title("Distribution of sample average duration of O_date_2_delivered")
plt.xlabel("Duration of O_date_2_delivered")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(merged_metric_2['date_diff_days'])
plt.title("Distribution of sample average duration of O_date_2_delivered")
plt.xlabel("Duration of O_date_2_delivered")
plt.ylabel("Frequency")
plt.show()

# %%
merged_metric_2['date_diff_days'].skew() # Checking skewness value  well within the expected bounds of  -0.5 and +0.5
# Out:
# np.float64(-0.8533228753311936)

# %%
merged_metric_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261 entries, 1699 to 5003
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order id           261 non-null    object
#  1   order date         261 non-null    datetime64[ns]
#  2   ship mode          261 non-null    object
#  3   customer id        261 non-null    object
#  4   country/region     261 non-null    object
#  5   city               261 non-null    object
#  6   state              261 non-null    object
#  7   postal code        261 non-null    float64
#  8   region             261 non-null    object
#  9   arrival scan date  261 non-null    datetime64[ns]
#  10  date_diff          261 non-null    timedelta64[ns]
#  11  date_diff_days     261 non-null    int64
#  12  order_weekday      261 non-null    object
#  13  arrival_weekday    261 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(9), timedelta64[ns](1)
# memory usage: 30.6+ KB

# %% [markdown]
# ### skewness is quite high, we should adopt bootstrapping method

# %%
# using bootstrapping: create a function

# Step 1: Calculate the sample petal length mean
sample_mean_metric_4 = merged_metric_2['date_diff_days'].mean()
print(f"Sample average duration of O_date_2_delivered : {sample_mean_metric_4:.2f}")

# Step 2: Define a bootstrapping function to calculate the CI
def bootstrap_ci(data, n, num_bootstrap=10000, confidence_level=0.95):
    bootstrapped_means = []
    n=len(merged_metric_2)
    for _ in range(num_bootstrap):
        sample = np.random.choice(data, size=n, replace=True)
        bootstrapped_means.append(np.mean(sample))
    
    # CI bounds
    lower_bound = np.percentile(bootstrapped_means, (1 - confidence_level) / 2 * 100)
    upper_bound = np.percentile(bootstrapped_means, (1 + confidence_level) / 2 * 100)
    return lower_bound, upper_bound, bootstrapped_means

# Step 3: Run bootstrapping
ci_lower, ci_upper, bootstrapped_means = bootstrap_ci(merged_metric_2['date_diff_days'], n=n_metric_4, num_bootstrap=10000, confidence_level=0.95)

print(f"95% Confidence Interval for the duration of O_date_2_delivered: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample average duration of O_date_2_delivered : 10.77
# 95% Confidence Interval for the duration of O_date_2_delivered: (10.43, 11.10)

# %%
# bootstrapped_means = [...]

mean_val = np.mean(bootstrapped_means)
median_val = np.median(bootstrapped_means)
ci_lower = np.percentile(bootstrapped_means, 2.5)
ci_upper = np.percentile(bootstrapped_means, 97.5)

# Increase plot size
g = sns.displot(bootstrapped_means, kde=True, height=6, aspect=1.5)

# Add mean, median, and CI lines
plt.axvline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='blue', linestyle='-.', label=f'Median: {median_val:.2f}')
plt.axvline(ci_lower, color='green', linestyle=':', label=f'CI Lower: {ci_lower:.2f}')
plt.axvline(ci_upper, color='green', linestyle=':', label=f'CI Upper: {ci_upper:.2f}')

# Move legend outside and make it bigger
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12, markerscale=1.2)
plt.tight_layout()
plt.show()

# %%
#using z distribution
from scipy.stats import norm

z_score = norm.ppf(0.975) # Z-score since the data is normal and population params are known
margin_of_error = z_score * (sample_std_metric_4/ np.sqrt(n_metric_4))  
ci_lower = sample_mean_metric_4 - margin_of_error
ci_upper = sample_mean_metric_4 + margin_of_error

print(f"95% Confidence Interval for the duration of O_truck_2_delivered: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# 95% Confidence Interval for the duration of O_truck_2_delivered: (10.44, 11.10)

# %%
# Sample statistics
sample_mean = sample_mean_metric_4
sample_std = sample_std_metric_4
sample_median = sample_median_metric_4
n_metric_4 = len(merged_metric_2)  # Sample size

# 95% Confidence Interval using Z-distribution
z_score = norm.ppf(0.975)
margin_of_error = z_score * (sample_std / np.sqrt(n_metric_4))
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

# Define x-range around the mean
x = np.linspace(sample_mean - 4*sample_std, sample_mean + 4*sample_std, 1000)
y = norm.pdf(x, loc=sample_mean, scale=sample_std)

# Plot the normal curve
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Normal Distribution', color='blue')

# Shade 95% confidence interval
plt.fill_between(x, y, where=(x >= ci_lower) & (x <= ci_upper), color='lightblue', alpha=0.5, label='95% CI')

# Mark mean and median
plt.axvline(sample_mean, color='green', linestyle='-', linewidth=2, label=f'Mean = {sample_mean:.2f}')
plt.axvline(sample_median, color='purple', linestyle='--', linewidth=2, label=f'Median = {sample_median:.2f}')

# Mark CI bounds
plt.axvline(ci_lower, color='red', linestyle='--', label=f'CI Lower = {ci_lower:.2f}')
plt.axvline(ci_upper, color='red', linestyle='--', label=f'CI Upper = {ci_upper:.2f}')

# Labels
plt.title('Normal Distribution with 95% Confidence Interval')
plt.xlabel('Duration of O_date_2_processed')
plt.ylabel('Probability Density')

# Legend outside
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 95% Confidence Interval: (10.44, 11.10)

# %%
# another way to calculate the ci_lower and ci_upper
data_metric_4 = merged_metric_2['date_diff_days'].dropna()  # drop missing values if any

# Sample statistics
mean_metric_4 = np.mean(data_metric_4)
sem_metric_4 = stats.sem(data_metric_4)   # Standard error of the mean

# 95% confidence interval
ci = stats.norm.interval(confidence=0.95, loc=mean_metric_4, scale=sem_metric_4)
print("Mean:", mean_metric_4)
print("95% CI:", ci)
print("Sem", sem_metric_4)
# Out:
# Mean: 10.770114942528735
# 95% CI: (np.float64(10.435475583930605), np.float64(11.104754301126865))
# Sem 0.17073750397340054

# %%
#using t distribution

from scipy import stats

df = n_metric_4
t_crit = stats.t.ppf(0.975, df).round(2)
print(f't_cri: {t_crit}')

# t-critical value for 95% confidence
t_crit = stats.t.ppf(0.975, df=n_metric_4-1)

# Margin of error
margin_error = t_crit * (sample_std_metric_4 / np.sqrt(n_metric_4))

# Confidence interval
ci_lower = sample_mean_metric_4  - margin_error
ci_upper = sample_mean_metric_4  + margin_error

print(f"95% Confidence Interval for the duration of O_truck_2_delivered: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# t_cri: 1.97
# 95% Confidence Interval for the duration of O_truck_2_delivered: (10.43, 11.11)

# %%
# Sample statistics
sample_mean = sample_mean_metric_4
sample_std = sample_std_metric_4
sample_median = sample_median_metric_4
n_metric_4 = len(merged_metric_2)  # Sample size
df = n_metric_4 - 1  # degrees of freedom

# Standard error
SE = sample_std / np.sqrt(n_metric_4)

# t-critical value for 95% confidence
t_crit = stats.t.ppf(0.975, df=df)

# Margin of error
margin_error = t_crit * SE

# Confidence interval
ci_lower = sample_mean - margin_error
ci_upper = sample_mean + margin_error
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

# Define x-range around the mean
x = np.linspace(sample_mean - 4*SE, sample_mean + 4*SE, 1000)

# Correctly scaled t-distribution PDF
y = stats.t.pdf((x - sample_mean) / SE, df=df) / SE

# Plot the t-distribution curve
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='t-Distribution', color='blue')

# Shade 95% confidence interval
plt.fill_between(x, y, where=(x >= ci_lower) & (x <= ci_upper), color='lightblue', alpha=0.5, label='95% CI')

# Mark mean
plt.axvline(sample_mean, color='green', linestyle='-', linewidth=2, label=f'Mean = {sample_mean:.2f}')

# Mark median
plt.axvline(sample_median, color='purple', linestyle='-.', linewidth=2, label=f'Median = {sample_median:.2f}')

# Mark CI bounds
plt.axvline(ci_lower, color='red', linestyle='--', label=f'CI Lower = {ci_lower:.2f}')
plt.axvline(ci_upper, color='red', linestyle='--', label=f'CI Upper = {ci_upper:.2f}')

# Labels
plt.title('t-Distribution with 95% Confidence Interval')
plt.xlabel('Duration of O_date_2_processed')
plt.ylabel('Probability Density')

# Legend outside
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 95% Confidence Interval: (10.43, 11.11)
